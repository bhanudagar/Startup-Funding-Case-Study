# %% [markdown]
# ## Scenario 7 - Funding Rounds
#
# Given File 'startup_funding.csv'
# #### Problem Statement :
# 1. Find the top 5 startups who received the most number of funding rounds. That means, startups which got fundings maximum number of times.
# 2. Print the startup name in descending order with respect to the number of funding round as integer value.
# #### Note:
# 1. Ola, Flipkart, Oyo, Paytm are important startups, so correct their names. There are many errors in startup names, ignore correcting all, just handle important ones.
#
# ### Output Format :
# #### startup1 number1
# #### startup2 number2
# #### startup3 number3
# #### . . .

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('startup_funding.csv')
df.head()
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# ...

# %%
df.StartupName.fillna('', inplace = True)

startup_funding = {}
for i in range(len(df.StartupName)):
    currName = df.StartupName[i]
    startup_funding[currName] = startup_funding.get(currName, 0) + 1
    
startup_funding
# Out:
# {'TouchKin': 1,
#  'Ethinos': 1,
#  'Leverage Edu': 1,
#  'Zepo': 1,
#  'Click2Clinic': 1,
#  'Billion Loans': 1,
#  'Ecolibriumenergy': 1,
#  'Droom': 2,
#  'Jumbotail': 1,
#  'Moglix': 4,
#  'Timesaverz': 1,
#  'Minjar': 1,
#  'MyCity4kids': 1,
#  'Clip App': 1,
#  'Upwardly.in': 1,
#  'Autorox.co': 1,
#  'Fabogo': 1,
#  'Flickstree': 1,
#  'Design Cafe': 1,
#  'Innoviti': 2,
#  'VDeliver': 1,
#  'Bottr.me': 1,
#  'Arcatron': 1,
#  'QwikSpec': 1,
#  'Chumbak': 1,
#  'Increff': 1,
#  'Vayana': 1,
#  'MObiquest': 1,
#  'Ambee': 1,
#  'Ideal Insurance': 1,
#  'Hypernova Interactive': 1,
#  'Rentomojo': 1,
#  'AirCTO': 1,
#  'Playablo': 1,
#  'Trupay': 1,
#  'Brick2Wall': 1,
#  'FableStreet': 1,
#  'Monsoon Fintech': 1,
#  'MonkeyBox': 2,
#  'Noticeboard': 1,
#  'Byju’s': 4,
#  'Creator’s Gurukul': 1,
#  'Fab Hotels': 1,
#  'ThinkerBell': 1,
#  '1mg': 3,
#  'Jhakaas': 2,
#  'BigStylist': 2,
#  'Gympik.com': 1,
#  'Tripeur': 1,
#  'RentOnGo': 2,
#  'Goomo': 1,
#  'MaxMyWealth': 1,
# ...

# %%
ans = sorted(startup_funding.items(), key = lambda x : x[1], reverse = True)
ans
# Out:
# [('Swiggy', 7),
#  ('UrbanClap', 6),
#  ('Paytm', 5),
#  ('Medinfi', 5),
#  ('NoBroker', 5),
#  ('Jugnoo', 5),
#  ('Moglix', 4),
#  ('Byju’s', 4),
#  ('Ola', 4),
#  ('Flipkart', 4),
#  ('Niki.ai', 4),
#  ('YepMe', 4),
#  ('Capital Float', 4),
#  ('Ola Cabs', 4),
#  ('HolaChef', 4),
#  ('Wooplr', 4),
#  ('Voonik', 4),
#  ('TinyStep', 4),
#  ('Simplilearn', 4),
#  ('Vyomo', 4),
#  ('Tracxn', 4),
#  ('1mg', 3),
#  ('LendingKart', 3),
#  ('Goodbox', 3),
#  ('EazyDiner', 3),
#  ('Fynd', 3),
#  ('Delhivery', 3),
#  ('Magicpin', 3),
#  ('Box8', 3),
#  ('Supr Daily', 3),
#  ('StalkBuyLove', 3),
#  ('Zapr', 3),
#  ('Rivigo', 3),
#  ('Licious', 3),
#  ('BigBasket', 3),
#  ('Icertis', 3),
#  ('Zenatix', 3),
#  ('Wassup', 3),
#  ('Truebil', 3),
#  ('Urban Ladder', 3),
#  ('LensKart', 3),
#  ('Square Yards', 3),
#  ('BookEventz', 3),
#  ('Nykaa', 3),
#  ('Zoomcar', 3),
#  ('Koovs', 3),
#  ('WorkIndia', 3),
#  ('Furlenco', 3),
#  ('RailYatri', 3),
#  ('Quikr', 3),
#  ('MyTaxiIndia', 3),
# ...

# %% [markdown]
# ### As we already know from the previous question, we need to clean our data. Basically, we need to correct the spellings of top startups. Let's do this

# %%
df.StartupName.replace('Ola Cabs', 'Ola', inplace = True)
df.StartupName.replace('Olacabs', 'Ola', inplace = True)
df.StartupName.replace('Oyo Rooms', 'Oyo', inplace = True)
df.StartupName.replace('Paytm Marketplace', 'Paytm', inplace = True)
df.StartupName.replace('Oyorooms', 'Oyo', inplace = True)
df.StartupName.replace('OyoRooms', 'Oyo', inplace = True)
df.StartupName.replace('OYO Rooms', 'Oyo', inplace = True)
df.StartupName.replace('Flipkart.com', 'Flipkart', inplace = True)

# %%
startup_funding = {}
for i in range(len(df.StartupName)):
    currName = df.StartupName[i]
    startup_funding[currName] = startup_funding.get(currName, 0) + 1
    
ans = sorted(startup_funding.items(), key = lambda x : x[1], reverse = True)
ans = ans[:5]

# %%
for i in range(5):
    print(ans[i][0], ans[i][1])
# Out:
# Ola 9
# Swiggy 7
# UrbanClap 6
# Paytm 6
# Oyo 6

# %% [markdown]
# ### Creating a Bar Graph for the top 5 startups

# %%
startup = []
number_of_fundings = []
for i in range(5):
    startup.append(ans[i][0])
    number_of_fundings.append(ans[i][1])

# %%
plt.bar(startup, number_of_fundings, color = 'teal', width = 0.5)
plt.xticks(rotation = 40)
plt.yticks(np.arange(10))
plt.xlabel('Startup Names')
plt.ylabel('Number of Fundings')
plt.title('Startups with number of fundings in each')
plt.grid()
plt.show()
