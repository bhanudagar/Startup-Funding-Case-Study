# %% [markdown]
# ## Scenario 6 - Top startups
#
# Given File 'startup_funding.csv'
# #### Problem Statement :
# 1. Find top 5 startups with most amount of total funding.
# 2. Print the startup name in descending order with respect to amount of funding.
# #### Note:
# 1. Ola, Flipkart, Oyo, Paytm are important startups, so correct their names. There are many errors in startup names, ignore correcting all, just handle important ones.
#
# ### Output Format :
# #### city1 percent1
# #### city2 percent2
# #### city3 percent3
# #### . . .
# #### . . .
# #### . . .

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("startup_funding.csv")
df.head()
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# 2  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3  Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                     Narottam Thudi, Shireesh Palle    Seed Funding
#
#   AmountInUSD Remarks
# 0   1,300,000     NaN
# 1         NaN     NaN
# 2         NaN     NaN
# 3     500,000     NaN
# 4     850,000     NaN

# %% [markdown]
# ### Creating amount and startup arrays to work upon and then converting amount elements from string to integer type

# %%
df.AmountInUSD.fillna('0', inplace = True)
df.StartupName.fillna('', inplace = True)

amount = np.array(df.AmountInUSD)
startup = np.array(df.StartupName)

for i in range(len(amount)):
    val = amount[i]
    a = val.split(',')
    currAmt = ''
    for j in a:
        currAmt += j
    amount[i] = int(float(currAmt))
    
amount = np.array(amount, dtype = float)
amount = np.array(amount, dtype = int)

# %% [markdown]
# ### Creating the startup - amount dictionary

# %%
print(len(amount))
print(len(startup))
# Out:
# 2372
# 2372

# %%
startup_amount = {}
for i in range(len(amount)):
    current_startup = startup[i]
    
    startup_amount[current_startup] = startup_amount.get(current_startup, 0) + amount[i]
    
startup_amount
# Out:
# {'TouchKin': 1300000,
#  'Ethinos': 0,
#  'Leverage Edu': 0,
#  'Zepo': 500000,
#  'Click2Clinic': 850000,
#  'Billion Loans': 1000000,
#  'Ecolibriumenergy': 2600000,
#  'Droom': 20000000,
#  'Jumbotail': 8500000,
#  'Moglix': 16200000,
#  'Timesaverz': 1000000,
#  'Minjar': 0,
#  'MyCity4kids': 0,
#  'Clip App': 1000000,
#  'Upwardly.in': 0,
#  'Autorox.co': 3000000,
#  'Fabogo': 2250000,
#  'Flickstree': 464000,
#  'Design Cafe': 0,
#  'Innoviti': 23350000,
#  'VDeliver': 0,
#  'Bottr.me': 0,
#  'Arcatron': 0,
#  'QwikSpec': 540000,
#  'Chumbak': 1700000,
#  'Increff': 2000000,
#  'Vayana': 4000000,
#  'MObiquest': 0,
#  'Ambee': 0,
#  'Ideal Insurance': 0,
#  'Hypernova Interactive': 0,
#  'Rentomojo': 10000000,
#  'AirCTO': 0,
#  'Playablo': 600000,
#  'Trupay': 700000,
#  'Brick2Wall': 200000,
#  'FableStreet': 0,
#  'Monsoon Fintech': 0,
#  'MonkeyBox': 0,
#  'Noticeboard': 1200000,
#  'Byju’s': 160000000,
#  'Creator’s Gurukul': 0,
#  'Fab Hotels': 25000000,
#  'ThinkerBell': 200000,
#  '1mg': 30000000,
#  'Jhakaas': 155000,
#  'BigStylist': 2150000,
#  'Gympik.com': 0,
#  'Tripeur': 0,
#  'RentOnGo': 0,
#  'Goomo': 50000000,
#  'MaxMyWealth': 0,
#  'Spinny': 1000000,
#  'Healthbuds': 0,
#  'Ftcash': 0,
#  'BHIVE Workspace': 1200000,
#  'wayForward': 1000000,
#  'GyanDhan': 0,
#  'Hungry Foal': 0,
#  'ZipLoan': 650000,
#  'GrowFitter': 600000,
#  'Stratfit': 232000,
#  'Multiplier Solutions': 1500000,
#  'ABI Health': 1500000,
#  'Stockal': 350000,
#  'Guidoo': 300000,
#  'eSahai.in': 250000,
#  'Loanmeet': 0,
#  'LendingKart': 44450000,
#  'Boxx.ai': 500000,
#  'PeeSafe.in': 1000000,
#  'Vista Rooms': 776000,
#  'CoverFox': 15000000,
#  'HyperTrack': 0,
#  'Goodera': 5500000,
#  'Digit': 0,
#  'Ola': 984500000,
#  'Vanitycask': 0,
#  'MrNeeds': 500000,
#  'MoneyTap': 12300000,
#  'Goodbox': 3700000,
#  'Fincash': 100000,
#  'PortDesk': 2000000,
#  'EdgeFx': 0,
#  'EazyDiner': 3000000,
#  'HealthIntel': 0,
#  'Unbxd': 12500000,
#  'DarwinBox': 4000000,
#  'ForeverShop': 300000,
#  'Insider.in': 5200000,
#  'Fynd': 3400000,
#  'Grow Fit': 4500000,
#  'Fabulyst': 215000,
#  'mSwipe': 31000000,
#  'OneAssist': 7500000,
#  'Julia Computing': 5200000,
#  'Kissht': 2000000,
#  'Explore Life traveling': 500000,
#  'Loantap': 4000000,
#  'Voxweb': 1350000,
#  'HUG Innovations': 5000000,
#  'Flipkart': 1559700000,
#  'V Resorts': 4000000,
#  'Stashfin': 5000000,
#  'Formcept': 0,
#  'Spares Hub': 311000,
#  'FiTraQ': 0,
#  'Rubique': 3000000,
#  'Niki.ai': 2000000,
#  'Fitpass': 2000000,
#  'ZingHR': 0,
#  'Tagos Design': 5000000,
#  'UrbanClap': 60700000,
#  'Ace2three': 73700000,
#  'Power2SME': 31000000,
#  'Innovapptive': 1500000,
#  '4tigo': 10000000,
#  'SMECorner': 0,
#  'ZippServe': 390000,
#  'Sumeru': 1000000,
#  'Healthians': 3000000,
#  'HealthMir': 0,
#  'Uactive': 0,
#  'i-lend': 0,
#  'Good Methods Global': 0,
#  'Balance App': 233000,
#  'YepMe': 88700000,
#  'Nightstay': 0,
#  'Devourin': 0,
#  'MyGreens': 1000000,
#  'Ace Turtle': 5000000,
#  'CureFit': 3000000,
#  'Curie Labs': 50000,
#  'Uncanny Vision': 0,
#  'Anchanto': 0,
#  'Sequretek': 0,
#  'Lucideus': 0,
#  'Vidooly': 2400000,
#  'Shopclues': 107700000,
#  'Fourth Ambit': 600000,
#  'Chymera VR': 0,
#  'Early Salary': 4000000,
#  'Book My Diamond': 0,
#  'ION Energy': 0,
#  'Legal Raasta': 5000000,
#  'Log 9 Materials': 0,
#  'Remit Guru': 466000,
#  'Aequm': 1000000,
#  'Zapty': 500000,
#  'Vernacular.ai': 0,
#  'Telr': 3000000,
#  'Genie': 250000,
#  'Paysense': 5300000,
#  'The Good Life': 1000000,
#  'PumpKart': 0,
#  'Paytm': 2140000000,
#  'EzCred': 1000000,
#  'HealthSutra': 0,
#  'Delhivery': 215000000,
#  'ZipGrid': 500000,
#  'TravelSpice': 0,
#  'Magicpin': 16600000,
#  'The Print': 0,
#  'Box8': 12000000,
#  'GenNext Students': 580000,
#  'Aye Finance': 11000000,
#  'WhatsLoan': 0,
#  'Cube Consumer Services': 0,
#  'Nivesh': 0,
#  'Wowflux': 0,
#  'Collateral Medical': 3500000,
#  'Loadshare': 0,
#  'SimpliLend': 0,
#  'Supr Daily': 1620000,
#  'Swiggy': 170500000,
#  'SastaSundar': 5000000,
#  'Cashe': 3800000,
#  'Eruditus': 8200000,
#  'TestBook': 0,
#  'Healthcare at Home': 40000000,
#  'Tyre Express': 0,
#  'SmartCoin': 0,
#  'WayCool': 2700000,
#  'Perfios': 6100000,
#  'Whatfix': 4590000,
#  'ElastiRun': 7000000,
#  'Trukky': 745000,
#  'Konsult App': 500000,
#  'Credit Sudhaar': 0,
#  'Fingerlix': 3000000,
#  'DataWeave': 0,
#  'Medwell Ventures': 31000000,
#  'Mech Mocha': 6000000,
#  'Startup Buddy': 0,
#  'QorQI': 0,
#  'Twenty Two Motors': 0,
#  'PharmEasy': 18000000,
#  'WonderChef': 0,
#  'FastFox': 4600000,
#  'Omnify': 150000,
#  'Capital Float': 42800000,
#  'Ninjacart': 8500000,
#  'MergerWare': 100000,
#  'Sports Flashes': 0,
#  'Clovia': 9000000,
#  'Emiza': 4500000,
#  'HackerEarth': 4500000,
#  'Squadrun': 2100000,
#  'Tinmen': 0,
#  'ScoutMyTrip': 0,
#  'SafetyKart': 0,
#  'WeAreHolidays': 7700000,
#  'Ola Cabs': 515000000,
#  'Myly': 410000,
#  'CrediHealth': 1500000,
#  'Navia Life Care': 0,
#  'Raw Pressery': 0,
#  'Snackible': 175000,
#  'Be U Salons': 620000,
#  'Simulanis': 0,
#  'Innefu Security Consulting': 2000000,
#  'Whodat': 600000,
#  'Absentia VR': 1250000,
#  'IOTrek': 155000,
#  'HolaChef': 5275000,
#  'Wooplr': 8000000,
#  'Video Ken': 1000000,
#  'Faasos': 36300000,
#  'Oyo Rooms': 350000000,
#  'Toppr': 13200000,
#  'Niramai': 0,
#  'The Office Pass': 245000,
#  'Awfis': 20000000,
#  'Myra': 0,
#  'Flytxt': 22000000,
#  'Howdy Ventures': 1500000,
#  'StalkBuyLove': 1000000,
#  'ZipGo': 0,
#  'Scootsy': 3600000,
#  'Autobix': 0,
#  'eShiksha': 0,
#  'iNurture': 1500000,
#  'Sepalika': 750000,
#  'Mintwalk': 0,
#  'Qriyo': 160000,
#  'Belong': 10000000,
#  'Seenit': 0,
#  'Paalak': 0,
#  'Celes Care': 2500000,
#  'Karomi': 500000,
#  'Red Carpet': 2500000,
#  'Kreate Konnect': 0,
#  'CreditMantri': 10100000,
#  'Lets Endorse': 0,
#  'Tydy': 275000,
#  'Nactus': 0,
#  'Oho Shop': 6700000,
#  'Emojifi': 0,
#  'Paytm Marketplace': 200000000,
#  'iGenetics': 19500000,
#  'Juno Clinic': 1200000,
#  'Summerlabel': 150000,
#  'PickMe': 1790000,
#  'Agrostar': 14000000,
#  'Zapr': 10000000,
#  'Data Resolve': 1000000,
#  'Book Servicing': 30000,
#  'Blowhorn': 3650000,
#  'Rivigo': 120000000,
#  'PipeCandy': 1100000,
#  'Parentune': 0,
#  'AppBrowzer': 500000,
#  'MagicBricks': 4500000,
#  'PeeBuddy': 443000,
#  'iOrderFresh': 0,
#  'Lavelle Networks': 600000,
#  'PropertyShare': 0,
#  'MyDermacy': 0,
#  'LatestOne': 6350000,
#  'Frapperz': 100000,
#  'mPaani': 1350000,
#  'ShilpMIS': 0,
#  'POPxo': 3100000,
#  'Fitso': 400000,
#  'FarMart': 0,
#  'Airpay': 3670000,
#  'MyGlamm': 11300000,
#  'The Mons Co.': 0,
#  'Haqdarshak': 191000,
#  'Ixigo': 15000000,
#  'Markets and Markets': 56000000,
#  'Bizom': 382000,
#  'BabyonBoard': 0,
#  'Sport Flashes': 0,
#  'Wigzo': 500000,
#  'DoneThing': 300000,
#  'Zapyle': 1000000,
#  'Ithaka': 325000,
#  'perpule': 650000,
#  'Licious': 14000000,
#  'Medinfi': 655000,
#  'Indus OS': 5000000,
#  'Emflux Motors': 0,
#  'Klinic App': 0,
#  'Oriano Solar': 3000000,
#  'BigBasket': 207000000,
#  'Rooter': 0,
#  'FalconBrick': 0,
#  'Icertis': 46000000,
#  'Clodura': 0,
#  'Stockroom.io': 70000,
#  'iManageMyHotel': 0,
#  'Inner Hour': 450000,
#  'Travel Triangle': 18000000,
#  'Wandertrails': 1000000,
#  'Zenatix': 1361000,
#  'Cartrade': 55000000,
#  'MindYourFleet': 0,
#  'Edurev': 40000,
#  'Voonik': 34000000,
#  '1Crowd': 0,
#  '48East': 500000,
#  'Redesyn': 0,
#  'Sigtuple': 5800000,
#  'Flutura': 7500000,
#  'Wassup': 5200000,
#  'Better Mortgage': 15000000,
#  'Nurturey': 455000,
#  'Fyle': 400000,
#  'GoBumpr': 300000,
#  'CCAvenue': 22400000,
#  'Connaizen': 0,
#  'Innov8': 0,
#  'ZestMoney': 6500000,
#  'AirZaar': 350000,
#  'Truebil': 8650000,
#  'YourStory': 3000000,
#  'Imaginate': 500000,
#  'The Ken': 400000,
#  'Urban Ladder': 65200000,
#  'Aisle': 185000,
#  'TownScript': 0,
#  'Leopetra': 40000,
#  'Blood n Care': 40000,
#  'True Balance': 15000000,
#  'Vebbler': 540000,
#  'Get My Parking': 1476000,
#  'Lets Reap': 0,
#  'Oglas': 0,
#  'Staydobe': 0,
#  'Biryani By Kilo': 375000,
#  'Johari Shop': 94000,
#  'NeoStencil': 1000000,
#  'Blackbuck': 70000000,
#  'TaxSutra': 526000,
#  'TempoGo': 825000,
#  'GoFynd': 0,
#  'Vow Car Clinic': 0,
#  'LearnTron': 0,
#  'MobiDent': 0,
#  'Yostra': 0,
#  'Leap India': 13000000,
#  'FreeCharge': 137000000,
#  'TicketNew': 35000000,
#  'Intelligence Node': 800000,
#  'Securens': 5000000,
#  'Loan Frame': 2250000,
#  'DriveSkool': 0,
#  'LensKart': 5650000,
#  'InstaOffice': 0,
#  'Hansel.io': 1350000,
#  'Square Yards': 28000000,
#  'Roambee': 4100000,
#  'PaisaWapas': 0,
#  'iService': 440000,
#  'Unacademy': 5000000,
#  'SecururAX': 0,
#  'Leadburg': 0,
#  'ZoloStays': 5000000,
#  'Oi Media': 0,
#  'HipCouch': 700000,
#  'Curiositi': 800000,
#  'TinyStep': 3580000,
#  'Practo': 85000000,
#  'Ketchupp': 441000,
#  'Hoopy': 500000,
#  'Ezytruk': 147000,
#  'Kratikal': 0,
#  'Direct Create': 0,
#  'Vahdam Teas': 650000,
#  'Qwikspec': 300000,
#  'PParke': 0,
#  'Weddingz.in': 2000000,
#  'Native Special': 0,
#  'Fitnapp': 0,
#  'Ethosh': 0,
#  'Wydr': 0,
#  'MessaGif': 50000,
#  'SmartHi': 0,
#  'CRON Systems': 0,
#  'CueMath': 19000000,
#  'ChipperSage': 0,
#  'SelectJobs': 0,
#  'Khel Now': 850000,
#  'NowFloats': 10000000,
#  'Lets Transport': 4000000,
#  'BetaOut': 0,
#  'Wishberry': 650000,
#  'RML Agtech': 4000000,
#  'LoyaltyPrime': 0,
#  'InstaSafe': 2200000,
#  'Infibeam': 8800000,
#  '99Games': 0,
#  'AirMed Labs': 1400000,
#  '99PerHour': 300000,
#  'Kochi Post': 0,
#  'Intuit Things': 106000,
#  'Cloudrino': 22500,
#  'FabX': 68000,
#  'Maptags': 18000,
#  'YOLO Health': 0,
#  'Heads Up For Tails': 3000000,
#  'Register My Marriage': 0,
#  'SidQam': 1200000,
#  'India Lends': 4000000,
#  'Slide App': 3600000,
#  'Badiyajobs': 100000,
#  'Streo': 0,
#  'TYGR': 3000000,
#  'Mr Hot Foods': 0,
#  'UrDoorStep': 1400000,
#  'ONN Bikes': 0,
#  'Diro Labs': 597000,
#  'THB': 0,
#  'LookAtMe': 0,
#  'Netree': 0,
#  'BookEventz': 0,
#  'Tailslife': 0,
#  'Revv': 9000000,
#  'WealthApp': 440000,
#  'Vehico': 0,
#  'Zest Money': 6500000,
#  'GoMechanic': 250000,
#  'Stalk Buy Love': 6000000,
#  'Nykaa': 21800000,
#  'Wittyparot': 450000,
#  'NeuroEquilibrium': 250000,
#  'Xseed Education': 10000000,
#  'Rupaiya Exchange': 200000,
#  'Doctor Insta': 2500000,
#  'UrbanPiper': 0,
#  'Fresh Food Concepts': 2000000,
#  'Indifi': 10000000,
#  'GoComet': 0,
#  'OfBusiness': 16100000,
#  'Fitmein': 0,
#  'Qacco': 150000,
#  'MoEngage': 4250000,
#  'Ten3t Health': 0,
#  'Trading Bells': 297000,
#  'SERV’D': 100000,
#  'IdeaForge': 10000000,
#  'Amagi Media Labs': 35000000,
#  'Pocket Aces': 3000000,
#  'Pi Data Centers': 23000000,
#  'TripShelf': 373000,
#  'Events High': 0,
#  'NoBroker': 20400000,
#  'VivoCarat': 50000,
#  'Tiyo': 0,
#  'Zoomcar': 16000000,
#  'BYJU’s': 15000000,
#  'The BlueBook': 500000,
#  'MamaEarth': 0,
#  'Vegetall': 162000,
#  'Innoplexus': 0,
#  'Mindler': 324000,
#  'MCaffeine': 300000,
#  'enKast': 2000000,
#  'ShopKirana': 0,
#  'MyAdvo': 0,
#  'Asocon': 0,
#  'LexComply': 0,
#  'The Postbox': 0,
#  'Pandorum Technologies': 0,
#  'Dekkho': 1200000,
#  'Shadowfox': 10000000,
#  'ShopX': 5000000,
#  'Healthifyme': 1000000,
#  'LetsMD': 0,
#  'Justbooks': 0,
#  'InstantPay': 0,
#  'PickMyLaundry': 300000,
#  'FreshDesk': 55000000,
#  'LaundryAnna': 150000,
#  'Sattviko': 320000,
#  'Zarget': 7500000,
#  'DoSelect': 0,
#  'EasyPolicy': 10000000,
#  'Browntape': 0,
#  'Connect India': 6000000,
#  'Corseco': 150000,
#  'vImmune': 0,
#  'The Gourmet Jar': 0,
#  'Medzin': 45000,
#  'Bizongo': 3000000,
#  'JustRide': 5000000,
#  'IIM Jobs': 2000000,
#  'GolfLAN': 1000000,
#  'Yottaasys': 0,
#  'Tone Tag': 0,
#  'Life in Control': 0,
#  'Active.ai': 3500000,
#  'ElasticRun': 2000000,
#  'Zefo': 6000000,
#  'PlaySimple': 4000000,
#  'Stasis Labs': 5000000,
#  'Scienaptic': 0,
#  'Koovs': 23300000,
#  'Lawrato': 0,
#  'Trip Tap Toe': 0,
#  'Pictor Imaging': 147000,
#  'GramCover': 1000000,
#  'AerMed': 0,
#  'WorkIndia': 500000,
#  'Bats on delivery': 90000,
#  'numberz.in': 650000,
#  'Housing.com': 20000000,
#  'Awesummly': 147000,
#  'VoLT': 0,
#  'Vymo': 5000000,
#  'ShubhLoans': 0,
#  'Noddapp': 147000,
#  'Knowlarity': 20000000,
#  'Infisecure': 600000,
#  'Udaan': 10000000,
#  'FroyoFit': 0,
#  'Betterplace': 0,
#  'ShareChat': 5350000,
#  'UClean': 0,
#  'Servify': 0,
#  'Hubilo': 0,
#  'FunOnGo': 0,
#  '121Policy': 0,
#  'TapChief': 0,
#  'Kloseby': 100000,
#  'WholeSaleBox': 2000000,
#  'Crossahead': 0,
#  'Affordplan': 3500000,
#  'HandyTrain': 1000000,
#  'ShopsUp': 963000,
#  'Indofash': 150000,
#  'Entropika': 200000,
#  'MarianaIQ': 2000000,
#  'Chai Thela': 218000,
#  'Interviewpad': 100000,
#  'Math Buddy': 440000,
#  'Pulse': 500000,
#  'Carcrew.in': 500000,
#  'MeraKisan': 0,
#  'Mystifly': 5000000,
#  'HelpChat': 0,
#  'Uniphore': 2000000,
#  'World Art Community': 400000,
#  'Giftxoxo': 450000,
#  'Bharat Bazaar': 0,
#  'GOQii': 0,
#  'India Gifts Portal': 2000000,
#  'NetLinx': 3000000,
#  'Scandid': 0,
#  'Remitr': 1000000,
#  'InnerChef': 4250000,
#  'AppsDaily': 3750000,
#  'MuhurtMaza': 0,
#  'Azuro': 0,
#  'NeuroSynaptic': 0,
#  'UE LifeSciences': 1200000,
#  'FindmeaShoe': 0,
#  'RealBox': 300000,
#  'Sportido': 0,
#  'GoZefo': 1050000,
#  'RayIOT': 100000,
#  'KOOH Sports': 4200000,
#  'Flexiloans': 15000000,
#  'Sibia Analytics': 0,
#  'Vithi.com': 375000,
#  'Yupp TV': 50000000,
#  'Deyor Camps': 500000,
#  'FabAlley': 2000000,
#  'Shoekonnect': 0,
#  'Maya': 0,
#  'RoboVac': 450000,
#  'Newspatrolling': 25000,
#  'Postman': 8000000,
#  'ISFC': 6000000,
#  'BeatRoute': 0,
#  'Kidsstoppress': 0,
#  'DailyHunt': 25000000,
#  'Tazzo Bikes': 227000,
#  'MyKindofJob': 1000000,
#  'Trilyo': 0,
#  'Yumigo': 300000,
#  'Rentalpha': 16000000,
#  '3Dexter': 150000,
#  'BabyChakra': 0,
#  'Coppre': 0,
#  'MySUN': 2500000,
#  'ePathsala': 0,
#  'Furlenco': 41000000,
#  'Fisdom': 1600000,
#  'Actofit': 750000,
#  'Stayology': 0,
#  'Hipcask': 0,
#  'RailYatri': 0,
#  'ChatOnGo': 300000,
#  'WOTU': 0,
#  'Kredx': 6000000,
#  'CreditMate': 500000,
#  'Pickrr': 0,
#  'SatvaKart': 0,
#  'SooperMO': 100000,
#  'OrangeTwig': 1000000,
#  'The Kettlery': 1000000,
#  'Idea Bubbles': 700000,
#  'FR8': 971000,
#  'Ather Energy': 39000000,
#  'Pikkol': 0,
#  'Velmenni': 100000,
#  'Volta Motors': 100000,
#  'Cyclops': 100000,
#  'Impact Analytics': 750000,
#  'Talent Next': 1000000,
#  'Mad Street Den': 1500000,
#  'Mihup': 6700000,
#  'Renowala': 0,
#  'Trackbizz': 0,
#  'Social Quotient': 0,
#  'eShakti': 1350000,
#  'CheersOye!': 500000,
#  'Lenskart': 60000000,
#  'Zilingo': 9900000,
#  'Alternacare': 500000,
#  'Simplilearn': 35750000,
#  'Prozo': 520000,
#  'TopRankers': 670000,
#  'BuildTraders': 200000,
#  'Freshboxx': 0,
#  'CureInstant': 150000,
#  'Poshtic': 450000,
#  'KarmaCircles': 0,
#  'Purple Style Labs': 448000,
#  'Inuxu': 3000000,
#  'Glam Studios': 300000,
#  'Findow': 0,
#  'IdeaChakki': 0,
#  'ShoeKonnect': 0,
#  'NearBuy': 2500000,
#  'ZeroInfy': 0,
#  'Flocareer': 150000,
#  'LensPick': 0,
#  'infeedo': 200000,
#  'GoPigeon': 1500000,
#  'NewsDistill': 100000,
#  'DoctorInsta': 1000000,
#  'Milofy': 750000,
#  'Liqvid': 0,
#  'Codemojo': 0,
#  'JustLikeNew': 500000,
#  'JoeHukum': 0,
#  'Co Life': 1000000,
#  'PurpleDocs': 0,
#  'Pepperfry': 131300000,
#  'eQuickies': 298000,
#  'Gadgetwood': 6200000,
#  'DailyRounds': 0,
#  'Flixy Games': 425000,
#  'HashTaag': 1000000,
#  'PharmaRack': 745000,
#  'CloudCherry': 6000000,
#  'Parentlane': 0,
#  'First Moms Club': 0,
#  'inMotion': 0,
#  'Let’s Barter': 0,
#  'EvenGini': 0,
#  'Canvs': 0,
#  'Beardo': 500000,
#  'Instacar': 1000000,
#  'Druva': 51000000,
#  'Promon': 180000,
#  'Fastudent': 0,
#  'Unocoin': 1500000,
#  'Demyto': 0,
#  'Zeta': 19000000,
#  'Kalaage': 0,
#  'HealthKart': 12000000,
#  'RepairEasy': 275000,
#  'Tokri': 2500000,
#  'Sheroes': 2570000,
#  'Daily Ninja': 0,
#  'Yumlane': 1000000,
#  'Xcode': 0,
#  'ExtraCarbon': 225000,
#  'FlickBay': 890000,
#  'Petoo': 1500000,
#  'lehlehsports': 0,
#  'Tricog': 0,
#  'VST Travels': 27000,
#  'AdPushUp': 0,
#  'Wefly Indoor Skydiving': 40000,
#  'Mojarto': 445000,
#  'Zipgrid': 200000,
#  'Zeolr/RespirON': 0,
#  'Bombay Shaving Company': 600000,
#  'Travelyaari': 10000000,
#  '91SpringBoard': 0,
#  'Genextstudents': 209000,
#  'Zenoti': 15000000,
#  'Crofarm': 1500000,
#  'Faircent.com': 1750000,
#  'Innovaccer': 15600000,
#  'Cuberoot': 500000,
#  'Funcastic': 0,
#  'Buttercups': 0,
#  'Zappfresh': 77000,
#  'OyoRooms': 62000000,
#  'Hike': 175000000,
#  'Joolz': 500000,
#  'SaleBhai': 1500000,
#  'Makkajai': 250000,
#  'Gradopedia': 0,
#  'MaalGaadi': 375000,
#  'ZiPi': 0,
#  'Appknox': 675000,
#  'Meesho': 0,
#  'Sesame Software': 0,
#  'Quikr': 230000000,
#  'Digio': 375000,
#  'Ziffity': 0,
#  'Zzungry': 0,
#  'Puro Wellness': 37000000,
#  'Fitternity': 1000000,
#  'TAC Security': 0,
#  'Notesgen': 100000,
#  'NearU': 0,
#  'Octo.ai': 200000,
#  'ShaadiSaga': 0,
#  'UnaAcademy': 1000000,
#  'Advenio': 100000,
#  'Guarented': 500000,
#  'Beyond Evolution': 0,
#  'Uber Dreams': 500000,
#  'Convegenius': 1200000,
#  'UrbanLadder': 3000000,
#  'enCashea': 0,
#  'EngineerBabu': 0,
#  'Cult': 3000000,
#  'WitWorks': 0,
#  'NearFox': 0,
#  'ZoomCar': 24000000,
#  'Plix': 500000,
#  'Mobikwik': 90000000,
#  'MyDidi': 550000,
#  'CrownIt': 0,
#  'LoanTap': 3000000,
#  'Runnr': 7000000,
#  'Zolo': 0,
#  'Notion Press': 1000000,
#  'LivSpace': 15000000,
#  'iAugmentor Labs': 149000,
#  'DayBox': 104000,
#  'CropIn': 2000000,
#  'Canvera': 5200000,
#  'Prime Focus Technologies': 0,
#  'Flyrobe': 7000000,
#  'inclov': 0,
#  'RazorPay': 120000,
#  'Venture Catalysts': 500000,
#  'PressPlay TV': 0,
#  'Playment': 700000,
#  'WealthTrust': 0,
#  'Curefit': 15000000,
#  'StitchWood': 200000,
#  'Grab.in': 2000000,
#  'Fulfil.IO': 0,
#  'NeoGrowth': 16000000,
#  'SeeDoc': 1000000,
#  'BookMyShow': 82000000,
#  'HappilyUnmarried': 740000,
#  'Don’t Scratch Your Head': 250000,
#  'Wedding Wishlist': 297000,
#  'AppDaily': 2000000,
#  'Adytude': 1000000,
#  'Quickli': 0,
#  'SpectraVR': 0,
#  'Pitstop': 0,
#  'Purplle': 6000000,
#  'Trak N Tell': 3500000,
#  'Overcart.com': 3000000,
#  'SirionLabs': 12250000,
#  'MintM': 0,
#  'HitGrit': 0,
#  'Find My Stay': 0,
#  'YAAP': 5000000,
#  'Utoo Cabs': 0,
#  'Twigly': 800000,
#  'Urban Tailor': 0,
#  'RentMojo': 5000000,
#  'CityFurnish': 0,
#  'HEAL Institute': 0,
#  'Augrav': 450000,
#  'ShoppinPal': 1070000,
#  'TransTutors / AskIITians': 0,
#  'WorkApps': 1000000,
#  'BankerBay': 2000000,
#  'BaggOut': 0,
#  'SatvaCart': 0,
#  'Ridlr': 6000000,
#  'Yellowdig': 650000,
#  'Zuppler': 650000,
#  'BlueStone': 30000000,
#  'underDOGS': 0,
#  'ImageProVision': 0,
#  'Sagacito': 10000000,
#  'Deal4Loans / Wishfin': 15000000,
#  'NiYO Solutions': 1000000,
#  'AppLop': 250000,
#  'Tax2Win': 1000000,
#  'Truckola': 595000,
#  'iServe Financial': 0,
#  'MyTaxiIndia': 1600000,
#  'AbeRuk': 0,
#  'Wiwigo': 595000,
#  'Drums Food': 0,
#  'Chikoop': 0,
#  'BRIDGEi2I': 0,
#  'Visit': 0,
#  'Atomberg': 1000000,
#  'Coutloot': 0,
#  'Limo': 1000000,
#  'iCliniq': 0,
#  'GoGo Truck': 75000,
#  'Vyome Biosciences': 2000000,
#  'SillyMonks': 448000,
#  'KrazyBee': 2000000,
#  'Intgrea': 100000,
#  'HelpShift': 23000000,
#  'CreditVidya': 1000000,
#  'Grey Campus': 1000000,
#  'ListUp': 500000,
#  '6Degree': 200000,
#  'Shopwati': 0,
#  'Cookifi': 0,
#  'StoreKing': 16000000,
#  'Wired Hub': 0,
#  'MySeniorDoctor': 200000,
#  'Teabox': 6000000,
#  'ExtraaEdge': 0,
#  'EPayLater': 2000000,
#  'Kyazoonga': 0,
#  'Paytunes': 500000,
#  'Kickstart Jobs': 0,
#  'Freshee': 0,
#  'MadRat Games': 168000,
#  'Jazzmyride': 0,
#  'AutoSense': 0,
#  'Redsun Telematics': 0,
#  'KhanaGadi': 0,
#  'Bombay Shirt Company': 1000000,
#  'Matrubharti': 30000,
#  'EdTechReview': 0,
#  'Bonhomia': 3000000,
#  'Gobolt': 0,
#  'Jivox': 6000000,
#  'Sminq': 1000000,
#  'CureJoy': 5550000,
#  'Oneway.cab': 450000,
#  'GrabOnRent': 0,
#  'Unnati Helpers': 600000,
#  'Athletto': 0,
#  'Saavn': 100000000,
#  'ThinkPhi': 0,
#  'Cleartax': 14000000,
#  'Silvan Innovation Labs': 900000,
#  'GreytHR': 5200000,
#  'Duffl': 0,
#  'BYG': 0,
#  'Dipper': 0,
#  'Qonfuse': 0,
#  'The Indian IRIS': 0,
#  'Onspoon': 150000,
#  'REstate': 0,
#  'Cleartrip': 0,
#  'ProcMart': 0,
#  'Celerix': 400000,
#  'NatureNama': 225000,
#  'CyclopsMedtech': 0,
#  'Syona Cosmetics': 150000,
#  'PrettySecrets': 6000000,
#  'SpiderG': 150000,
#  'FarEye': 3500000,
#  'The Uolo': 210000,
#  'Staqu': 0,
#  'Padhopadhao': 0,
#  'Drivify': 50000,
#  'PratiLipi': 0,
#  'ParaBlu': 500000,
#  'Schedulers Logistics': 6000000,
#  'LEAP India': 3000000,
#  'KabadiExpress': 148000,
#  'YourDost': 1200000,
#  'Gomalon': 100000,
#  'Voler Cars': 0,
#  'FabHotels': 8000000,
#  'Locanix': 300000,
#  'Hello Tax': 295000,
#  'MySuperBrain': 0,
#  'BlogBeats': 0,
#  'LetReach': 200000,
#  'TrendieApp': 50000,
#  'ImpactGuru': 0,
#  'Velvetcase': 1500000,
#  'Meru Cabs': 75000000,
#  'Campus Diaries': 220000,
#  'Scripbox': 2500000,
#  'Biryani Blues': 368000,
#  'MotoMojo': 0,
#  'Prescribez': 145000,
#  'Airwood': 0,
#  'iDreamCareer': 0,
#  'Zwayam': 250000,
#  'BoiBanit': 0,
#  'Zuver': 180000,
#  'Prepathon': 0,
#  'EasyRoads': 200000,
#  'Seclore': 12000000,
#  'SolarTown': 200000,
#  'Comarete': 200000,
#  'MyDentistChoice': 150000,
#  'Indee': 500000,
#  'WebAlligator': 375000,
#  'EduAce Services': 1000000,
#  'Zebroads': 75000,
#  'Locus': 2750000,
#  'Toko Innovations': 450000,
#  'Rentickle': 250000,
#  'HealthifyMe': 6000000,
#  'InnoNano Research': 18000000,
#  'SchoolWear': 1500000,
#  'Zenify': 900000,
#  'Faircent': 0,
#  'Fractal Analytics': 100000000,
#  'Life Circle': 150000,
#  'Dream Wallets': 0,
#  'ShabdNagari': 0,
#  'Galleri5': 0,
#  'Derbii': 0,
#  'StayZilla': 13500000,
#  'WoW Express': 2200000,
#  'Smartivity': 1000000,
#  'BedBathMore': 0,
#  'Murgency': 0,
#  'Crownit': 0,
#  'Blinge': 0,
#  'TheSmartQ': 250000,
#  'PurpleHealth': 100000,
#  'Fundamentor': 0,
#  'EduPristine': 10000000,
#  'BhiveWorkspace': 1000000,
#  'Appie': 1000000,
#  'TaxiVaxi': 500000,
#  'Veqta': 500000,
#  'i2ifunding': 300000,
#  'EduRev': 0,
#  'Hoppingo': 89000,
#  'Eatonomist': 0,
#  'Goalwise': 1000000,
#  'Roast': 0,
#  'Address Health': 1500000,
#  'Arcatron Mobility': 100000,
#  'SheThePeople': 0,
#  'Consure Medical': 0,
#  'mChamp': 475000,
#  'Pianta': 0,
#  'Vahanalytics': 200000,
#  'Play Your Sport': 0,
#  'CCavenue': 8900000,
#  'Tpot': 0,
#  'MachaDalo': 175000,
#  'Dil Mil': 2700000,
#  'PicsDream': 0,
#  'Process 9': 0,
#  'Housing': 0,
#  'Roll Mafia': 0,
#  'Hungama': 25000000,
#  'Highway Delite': 0,
#  'Cult Fitness': 0,
#  'Haptik': 0,
#  'Shipsy': 1000000,
#  'gear6': 500000,
#  'Truly Social': 0,
#  ...}

# %%
ans = sorted(startup_amount.items(), key = lambda x : x[1], reverse = True)
ans
# Out:
# [('Paytm', 2140000000),
#  ('Flipkart', 1559700000),
#  ('Ola', 984500000),
#  ('Snapdeal', 700000000),
#  ('Flipkart.com', 700000000),
#  ('Ola Cabs', 515000000),
#  ('Olacabs', 400000000),
#  ('Oyo Rooms', 350000000),
#  ('Quikr', 230000000),
#  ('Delhivery', 215000000),
#  ('Foodpanda', 210000000),
#  ('BigBasket', 207000000),
#  ('Paytm Marketplace', 200000000),
#  ('MakeMyTrip', 180000000),
#  ('Hike', 175000000),
#  ('Swiggy', 170500000),
#  ('Grofers', 165000000),
#  ('Byju’s', 160000000),
#  ('CarTrade', 145000000),
#  ('FreeCharge', 137000000),
#  ('Ecom Express', 137000000),
#  ('Pepperfry', 131300000),
#  ('Rivigo', 120000000),
#  ('Shopclues', 107700000),
#  ('Saavn', 100000000),
#  ('Fractal Analytics', 100000000),
#  ('Oyo', 100000000),
#  ('Inmobi', 100000000),
#  ('Oyorooms', 100000000),
#  ('ShopClues', 100000000),
#  ('Mobikwik', 90000000),
#  ('practo', 90000000),
#  ('YepMe', 88700000),
#  ('Practo', 85000000),
#  ('Zomato', 85000000),
#  ('BookMyShow', 82000000),
#  ('Chillr', 76000000),
#  ('Meru Cabs', 75000000),
#  ('BillDesk', 75000000),
#  ('Ace2three', 73700000),
#  ('Blackbuck', 70000000),
#  ('Urban Ladder', 65200000),
#  ('Infogain', 63000000),
#  ('OyoRooms', 62000000),
#  ('UrbanClap', 60700000),
#  ('Lenskart', 60000000),
#  ('BankBazaar', 60000000),
#  ('Manthan', 60000000),
#  ('Markets and Markets', 56000000),
#  ('Antuit', 56000000),
#  ('Cartrade', 55000000),
#  ('FreshDesk', 55000000),
#  ('Naaptol', 52000000),
#  ('Druva', 51000000),
#  ('Goomo', 50000000),
#  ('Yupp TV', 50000000),
#  ('Netmeds.com', 50000000),
#  ('Zovi.com / Little App', 50000000),
#  ('Homelane', 50000000),
#  ('Freshdesk', 50000000),
#  ('CarDekho.com', 50000000),
#  ('RateGain', 50000000),
#  ('Icertis', 46000000),
#  ('Capillary Tech', 45000000),
#  ('Zo Rooms', 45000000),
#  ('LendingKart', 44450000),
#  ('Capital Float', 42800000),
#  ('Furlenco', 41000000),
#  ('Healthcare at Home', 40000000),
#  ('Peppertap', 40000000),
#  ('Zivame', 40000000),
#  ('Vistaar Finance', 40000000),
#  ('Applied Solar Technologies', 40000000),
#  ('PolicyBazaar', 40000000),
#  ('NewsHunt', 40000000),
#  ('Ather Energy', 39000000),
#  ('Portea Medical', 37500000),
#  ('Puro Wellness', 37000000),
#  ('Faasos', 36300000),
#  ('Simplilearn', 35750000),
#  ('TicketNew', 35000000),
#  ('Amagi Media Labs', 35000000),
#  ('EPS', 35000000),
#  ('Saama', 35000000),
#  ('Voonik', 34000000),
#  ('CraftsVilla', 34000000),
#  ('FreshMenu', 33500000),
#  ('MobiKwik', 31600000),
#  ('NestAway', 31300000),
#  ('mSwipe', 31000000),
#  ('Power2SME', 31000000),
#  ('Medwell Ventures', 31000000),
#  ('Caratlane.com', 31000000),
#  ('1mg', 30000000),
#  ('BlueStone', 30000000),
#  ('Roposo', 30000000),
#  ('Qubole', 30000000),
#  ('CredR', 30000000),
#  ('Grey Orange', 30000000),
#  ('Paper Boat', 30000000),
#  ('Axtria', 30000000),
#  ('deGustibus', 30000000),
#  ('LimeRoad.com', 30000000),
#  ('Square Yards', 28000000),
#  ('Sulekha.com', 28000000),
#  ('S Chand', 27000000),
#  ('Housejoy', 26500000),
#  ('Jugnoo', 26000000),
#  ('FirstCry', 26000000),
#  ('Fab Hotels', 25000000),
#  ('DailyHunt', 25000000),
#  ('Hungama', 25000000),
#  ('BlackBuck', 25000000),
#  ('Citrus Payment', 25000000),
#  ('Ezetap', 25000000),
#  ('IFMR Holdings', 25000000),
#  ('Mswipe', 25000000),
#  ('OYO Rooms', 25000000),
#  ('ZoomCar', 24000000),
#  ('Hopscotch', 24000000),
#  ('TinyOwl', 23500000),
#  ('Innoviti', 23350000),
#  ('Koovs', 23300000),
#  ('Pi Data Centers', 23000000),
#  ('HelpShift', 23000000),
#  ('CCAvenue', 22400000),
#  ('Flytxt', 22000000),
#  ('Nykaa', 21800000),
#  ('Naaptol.com', 21500000),
#  ('Roadrunnr', 21000000),
#  ('NoBroker', 20400000),
#  ('Droom', 20000000),
#  ('Awfis', 20000000),
#  ('Housing.com', 20000000),
#  ('Knowlarity', 20000000),
#  ('Just Buy Live', 20000000),
#  ('Shuttl', 20000000),
#  ('NDTV Wedding portal', 20000000),
#  ('GoJavas', 20000000),
#  ('Allygrow Technologies', 20000000),
#  ('MebelKart', 20000000),
#  ('News in shorts', 20000000),
#  ('MedGenome', 20000000),
#  ('Zopper', 20000000),
#  ('Groupon India', 20000000),
#  ('Faaso’s', 20000000),
#  ('Stayzilla', 20000000),
#  ('iGenetics', 19500000),
#  ('Loylty Rewards', 19350000),
#  ('CueMath', 19000000),
#  ('Zeta', 19000000),
#  ('PharmEasy', 18000000),
#  ('Travel Triangle', 18000000),
#  ('InnoNano Research', 18000000),
#  ('Craftstvilla', 18000000),
#  ('Culture Machine', 18000000),
#  ('Vyomo', 17000000),
#  ('Magicpin', 16600000),
#  ('Bidgely', 16600000),
#  ('Itzcash', 16500000),
#  ('Moglix', 16200000),
#  ('Bluestone', 16200000),
#  ('OfBusiness', 16100000),
#  ('Zoomcar', 16000000),
#  ('Rentalpha', 16000000),
#  ('NeoGrowth', 16000000),
#  ('StoreKing', 16000000),
#  ('NearBuy (previously\xa0 groupon India)', 16000000),
#  ('Droom.in', 16000000),
#  ('La Renon', 16000000),
#  ('Akosha', 16000000),
#  ('Aryaka', 16000000),
#  ('Appsdaily', 16000000),
#  ('Innovaccer', 15600000),
#  ('CoverFox', 15000000),
#  ('Ixigo', 15000000),
#  ('Better Mortgage', 15000000),
#  ('True Balance', 15000000),
#  ('BYJU’s', 15000000),
#  ('Flexiloans', 15000000),
#  ('Zenoti', 15000000),
#  ('LivSpace', 15000000),
#  ('Curefit', 15000000),
#  ('Deal4Loans / Wishfin', 15000000),
#  ('Transerv', 15000000),
#  ('Yuvi Hospitality', 15000000),
#  ('TaskBucks', 15000000),
#  ('Voylla', 15000000),
#  ('HolidayIQ', 15000000),
#  ('Arkin Net', 15000000),
#  ('Indix', 15000000),
#  ('Fintellix', 15000000),
#  ('Vserv', 15000000),
#  ('MoonFrog Labs', 15000000),
#  ('Mahindra First Choice', 15000000),
#  ('TruckingCube', 14900000),
#  ('Agrostar', 14000000),
#  ('Licious', 14000000),
#  ('Cleartax', 14000000),
#  ('Kartrocket', 14000000),
#  ('Coverfox', 14000000),
#  ('StayZilla', 13500000),
#  ('ZenDrive', 13500000),
#  ('Tracxn', 13500000),
#  ('NxtGen', 13500000),
#  ('GoQii', 13400000),
#  ('Toppr', 13200000),
#  ('Leap India', 13000000),
#  ('IndustryBuying', 13000000),
#  ('Nestaway', 12750000),
#  ('Unbxd', 12500000),
#  ('Xpressbees', 12500000),
#  ('MindTickle', 12500000),
#  ('MoneyTap', 12300000),
#  ('SirionLabs', 12250000),
#  ('Box8', 12000000),
#  ('HealthKart', 12000000),
#  ('Seclore', 12000000),
#  ('Robosoft', 12000000),
#  ('MyGlamm', 11300000),
#  ('Big Fish Ventures', 11100000),
#  ('Aye Finance', 11000000),
#  ('CupoNation', 11000000),
#  ('FundsIndia.com', 11000000),
#  ('Lybrate', 10200000),
#  ('CreditMantri', 10100000),
#  ('Rentomojo', 10000000),
#  ('4tigo', 10000000),
#  ('Belong', 10000000),
#  ('Zapr', 10000000),
#  ('NowFloats', 10000000),
#  ('Xseed Education', 10000000),
#  ('Indifi', 10000000),
#  ('IdeaForge', 10000000),
#  ('Shadowfox', 10000000),
#  ('EasyPolicy', 10000000),
#  ('Udaan', 10000000),
#  ('Travelyaari', 10000000),
#  ('Sagacito', 10000000),
#  ('EduPristine', 10000000),
#  ('The Viral Fever', 10000000),
#  ('Holisol Logistics', 10000000),
#  ('SportzVillage', 10000000),
#  ('Grabhouse', 10000000),
#  ('Attune Technologies', 10000000),
#  ('ChaiPoint', 10000000),
#  ('LogiNext', 10000000),
#  ('Lendingkart', 10000000),
#  ('Mamagoto', 10000000),
#  ('MySmartPrice', 10000000),
#  ('Trucksfirst', 10000000),
#  ('FirstCry.com', 10000000),
#  ('ZopNow', 10000000),
#  ('PepperTap', 10000000),
#  ('Babajobs', 10000000),
#  ('Arohan Financial Services', 10000000),
#  ('Smartairtrip.com', 10000000),
#  ('#Fame', 10000000),
#  ('NumberMall', 10000000),
#  ('Zilingo', 9900000),
#  ('Wizrocket', 9600000),
#  ('Clovia', 9000000),
#  ('Revv', 9000000),
#  ('QikPod', 9000000),
#  ('Razorpay', 9000000),
#  ('Shadowfax', 9000000),
#  ('CCavenue', 8900000),
#  ('Infibeam', 8800000),
#  ('Truebil', 8650000),
#  ('Fusion Microfinance', 8600000),
#  ('Jumbotail', 8500000),
#  ('Ninjacart', 8500000),
#  ('Opinio', 8300000),
#  ('Eruditus', 8200000),
#  ('MyDentist', 8200000),
#  ('Wooplr', 8000000),
#  ('Postman', 8000000),
#  ('FabHotels', 8000000),
#  ('Cloud Lending', 8000000),
#  ('Livspace', 8000000),
#  ('WeAreHolidays', 7700000),
#  ('Cube26', 7700000),
#  ('OneAssist', 7500000),
#  ('Flutura', 7500000),
#  ('Zarget', 7500000),
#  ('StyleTag', 7500000),
#  ('Collectabillia', 7500000),
#  ('HackerRank', 7500000),
#  ('SnapBizz', 7200000),
#  ('ElastiRun', 7000000),
#  ('Runnr', 7000000),
#  ('Flyrobe', 7000000),
#  ('Villgro', 6750000),
#  ('Oho Shop', 6700000),
#  ('Mihup', 6700000),
#  ('ZestMoney', 6500000),
#  ('Zest Money', 6500000),
#  ('Aasaanjobs', 6500000),
#  ('Avanti Learning', 6500000),
#  ('CultureAlley', 6500000),
#  ('LatestOne', 6350000),
#  ('Gadgetwood', 6200000),
#  ('Perfios', 6100000),
#  ('Mech Mocha', 6000000),
#  ('Stalk Buy Love', 6000000),
#  ('Connect India', 6000000),
#  ('Zefo', 6000000),
#  ('ISFC', 6000000),
#  ('Kredx', 6000000),
#  ('CloudCherry', 6000000),
#  ('Purplle', 6000000),
#  ('Ridlr', 6000000),
#  ('Teabox', 6000000),
#  ('Jivox', 6000000),
#  ('PrettySecrets', 6000000),
#  ('Schedulers Logistics', 6000000),
#  ('HealthifyMe', 6000000),
#  ('B9 Beverages', 6000000),
#  ('Chefs Basket', 6000000),
#  ('Welcome Cure', 6000000),
#  ('ManageMySpa', 6000000),
#  ('Veeba Foods', 6000000),
#  ('Treebo', 6000000),
#  ('The Porter', 6000000),
#  ('Zinka', 6000000),
#  ('1mg (Healthkartplus)', 6000000),
#  ('Lookup', 5880000),
#  ('Sigtuple', 5800000),
#  ('Juspay', 5800000),
#  ('Taskbob', 5700000),
#  ('LensKart', 5650000),
#  ('Patel Logistics', 5600000),
#  ('CureJoy', 5550000),
#  ('Goodera', 5500000),
#  ('Crown-it', 5500000),
#  ('TrulyMadly.com', 5500000),
#  ('ShareChat', 5350000),
#  ('Paysense', 5300000),
#  ('HolaChef', 5275000),
#  ('Insider.in', 5200000),
#  ('Julia Computing', 5200000),
#  ('Wassup', 5200000),
#  ('Canvera', 5200000),
#  ('GreytHR', 5200000),
#  ('HUG Innovations', 5000000),
#  ('Stashfin', 5000000),
#  ('Tagos Design', 5000000),
#  ('Ace Turtle', 5000000),
#  ('Legal Raasta', 5000000),
#  ('SastaSundar', 5000000),
#  ('Indus OS', 5000000),
#  ('Securens', 5000000),
#  ('Unacademy', 5000000),
#  ('ZoloStays', 5000000),
#  ('ShopX', 5000000),
#  ('JustRide', 5000000),
#  ('Stasis Labs', 5000000),
#  ('Vymo', 5000000),
#  ('Mystifly', 5000000),
#  ('YAAP', 5000000),
#  ('RentMojo', 5000000),
#  ('Jaypore', 5000000),
#  ('AlefMobitech', 5000000),
#  ('Melorra', 5000000),
#  ('HomeStudio', 5000000),
#  ('Shotang.com', 5000000),
#  ('Pokkt', 5000000),
#  ('Parcelled', 5000000),
#  ('Infoworks', 5000000),
#  ('Gozoomo', 5000000),
#  ('Liases Foras', 5000000),
#  ('Ameyo', 5000000),
#  ('Bona Vita', 5000000),
#  ('Hansa Customer Equity', 5000000),
#  ('belong', 5000000),
#  ('Vedantu', 5000000),
#  ('IndianRoots.com', 5000000),
#  ('Casa2inns', 5000000),
#  ('LocalOye', 5000000),
#  ('ChargeBee', 5000000),
#  ('DiabetOmics', 5000000),
#  ('Drivestream', 5000000),
#  ('Roposo.com', 5000000),
#  ('Wooplr.com', 5000000),
#  ('Commonfloor', 5000000),
#  ('Capricoast', 4750000),
#  ('Veritas Finance', 4700000),
#  ('FastFox', 4600000),
#  ('Whatfix', 4590000),
#  ('Grow Fit', 4500000),
#  ('Emiza', 4500000),
#  ('HackerEarth', 4500000),
#  ('MagicBricks', 4500000),
#  ('Customfurnish', 4500000),
#  ('HomeLane', 4500000),
#  ('Printvenue', 4500000),
#  ('Care24', 4350000),
#  ('MoEngage', 4250000),
#  ('InnerChef', 4250000),
#  ('KOOH Sports', 4200000),
#  ('IntelligenceNODE', 4200000),
#  ('NewsInShorts', 4150000),
#  ('Roambee', 4100000),
#  ('Vayana', 4000000),
#  ('DarwinBox', 4000000),
#  ('Loantap', 4000000),
#  ('V Resorts', 4000000),
#  ('Early Salary', 4000000),
#  ('Lets Transport', 4000000),
#  ('RML Agtech', 4000000),
#  ('India Lends', 4000000),
#  ('PlaySimple', 4000000),
#  ('medECUBE', 4000000),
#  ('Altizone', 4000000),
#  ('RKSV', 4000000),
#  ('icustommadeit', 4000000),
#  ('IMbesharam', 4000000),
#  ('Buildzar', 4000000),
#  ('ScoopWhoop', 4000000),
#  ('RevX', 4000000),
#  ('Reverie', 4000000),
#  ('Meritnation', 4000000),
#  ('Pastiwala', 4000000),
#  ('Cashe', 3800000),
#  ('AppsDaily', 3750000),
#  ('Goodbox', 3700000),
#  ('Cashkaro.com', 3700000),
#  ('Airpay', 3670000),
#  ('Blowhorn', 3650000),
#  ('Scootsy', 3600000),
#  ('Slide App', 3600000),
#  ('TinyStep', 3580000),
#  ('Collateral Medical', 3500000),
#  ('Active.ai', 3500000),
#  ('Affordplan', 3500000),
#  ('Trak N Tell', 3500000),
#  ('FarEye', 3500000),
#  ('Eat.Shop.Love', 3500000),
#  ('Fynd', 3400000),
#  ('Quintype', 3300000),
#  ('POPxo', 3100000),
#  ('Holachef', 3100000),
#  ('Autorox.co', 3000000),
#  ('EazyDiner', 3000000),
#  ('Rubique', 3000000),
#  ('Healthians', 3000000),
#  ('CureFit', 3000000),
#  ('Telr', 3000000),
#  ('Fingerlix', 3000000),
#  ('Oriano Solar', 3000000),
#  ('YourStory', 3000000),
#  ('Heads Up For Tails', 3000000),
#  ('TYGR', 3000000),
#  ('Pocket Aces', 3000000),
#  ('Bizongo', 3000000),
#  ('NetLinx', 3000000),
#  ('Inuxu', 3000000),
#  ('UrbanLadder', 3000000),
#  ('Cult', 3000000),
#  ('LoanTap', 3000000),
#  ('Overcart.com', 3000000),
#  ('Bonhomia', 3000000),
#  ('LEAP India', 3000000),
#  ('CollegeDekho', 3000000),
#  ('MyCity4Kids', 3000000),
#  ('CREO', 3000000),
#  ('Yumist', 3000000),
#  ('Jigsaw Academy', 3000000),
#  ('Whoop', 3000000),
#  ('HeyPillow', 3000000),
#  ('SchoolGuru', 3000000),
#  ('UE Life Sciences', 3000000),
#  ('Bestdealfinance', 3000000),
#  ('Doormint', 3000000),
#  ('Wudstay', 3000000),
#  ('Propstack', 3000000),
#  ('Fracktal Works', 3000000),
#  ('Lets Corp', 3000000),
#  ('Triphobo', 3000000),
#  ('MyNoticePeriod', 3000000),
#  ('Nimble Wireless', 3000000),
#  ('AgentDesks', 2950000),
#  ('Graphic India', 2800000),
#  ('Locus', 2750000),
#  ('WayCool', 2700000),
#  ('Dil Mil', 2700000),
#  ('Ecolibriumenergy', 2600000),
#  ('Renderlogy', 2600000),
#  ('Sheroes', 2570000),
#  ('Celes Care', 2500000),
#  ('Red Carpet', 2500000),
#  ('Doctor Insta', 2500000),
#  ('MySUN', 2500000),
#  ('NearBuy', 2500000),
#  ('Tokri', 2500000),
#  ('Scripbox', 2500000),
#  ('MyGubbi', 2500000),
#  ('EduBridge', 2500000),
#  ('Paynear', 2500000),
#  ('Flatchat', 2500000),
#  ('CustomFurnish.com', 2500000),
#  ('Crowdfire (formerly Justunfollow)', 2500000),
#  ('Grabhouse.com', 2500000),
#  ('Vidooly', 2400000),
#  ('TimeSaverz', 2400000),
#  ('Zimmber', 2400000),
#  ('trueHb', 2400000),
#  ('Pragmatix', 2400000),
#  ('iBus Networks', 2300000),
#  ('Mobikon', 2300000),
#  ('Fabogo', 2250000),
#  ('Loan Frame', 2250000),
#  ('Juggernaut', 2250000),
#  ('InstaSafe', 2200000),
#  ('WoW Express', 2200000),
#  ('Easypolicy', 2200000),
#  ('PressPlay', 2200000),
#  ('BigStylist', 2150000),
#  ('Squadrun', 2100000),
#  ('Increff', 2000000),
#  ('PortDesk', 2000000),
#  ('Kissht', 2000000),
#  ('Niki.ai', 2000000),
#  ('Fitpass', 2000000),
#  ('Innefu Security Consulting', 2000000),
#  ('Weddingz.in', 2000000),
#  ('Fresh Food Concepts', 2000000),
#  ('enKast', 2000000),
#  ('IIM Jobs', 2000000),
#  ('ElasticRun', 2000000),
#  ('WholeSaleBox', 2000000),
#  ('MarianaIQ', 2000000),
#  ('Uniphore', 2000000),
#  ('India Gifts Portal', 2000000),
#  ('FabAlley', 2000000),
#  ('CropIn', 2000000),
#  ('Grab.in', 2000000),
#  ('AppDaily', 2000000),
#  ('BankerBay', 2000000),
#  ('Vyome Biosciences', 2000000),
#  ('KrazyBee', 2000000),
#  ('EPayLater', 2000000),
#  ('Room On Call', 2000000),
#  ('Gingercrush', 2000000),
#  ('Godof Hospitals', 2000000),
#  ('Bluebirch', 2000000),
#  ('TruckMandi', 2000000),
#  ('POPxo.com', 2000000),
#  ('RentoMojo', 2000000),
#  ('Shopalyst', 2000000),
#  ('ZuperMeal', 2000000),
#  ('Tripoto', 2000000),
#  ('Toppr.com', 2000000),
#  ('RoomCentral', 2000000),
#  ('Fourth Partner Energy', 2000000),
#  ('Iqlect', 2000000),
#  ('Prothom', 2000000),
#  ('Uniken', 2000000),
#  ('ZapStitch', 2000000),
#  ('Plancess', 2000000),
#  ('UrbanPro', 2000000),
#  ('Fxkart.com', 2000000),
#  ('Satvacart', 1800000),
#  ('Sahayog Dairy', 1800000),
#  ('HeadOut', 1800000),
#  ('PickMe', 1790000),
#  ('Faircent.com', 1750000),
#  ('Teewe', 1750000),
#  ('Chumbak', 1700000),
#  ('Springboard', 1700000),
#  ('Supr Daily', 1620000),
#  ('Fisdom', 1600000),
#  ('MyTaxiIndia', 1600000),
#  ('WOW! MOMO', 1600000),
#  ('QuikWallet', 1600000),
#  ('Goodservice', 1600000),
#  ('Applicate', 1550000),
#  ('White Owl Brewery', 1530000),
#  ('Multiplier Solutions', 1500000),
#  ('ABI Health', 1500000),
#  ('Innovapptive', 1500000),
#  ('CrediHealth', 1500000),
#  ('Howdy Ventures', 1500000),
#  ('iNurture', 1500000),
#  ('Mad Street Den', 1500000),
#  ('GoPigeon', 1500000),
#  ('Unocoin', 1500000),
#  ('Petoo', 1500000),
#  ('Crofarm', 1500000),
#  ('SaleBhai', 1500000),
#  ('Velvetcase', 1500000),
#  ('SchoolWear', 1500000),
#  ('Address Health', 1500000),
#  ('RenewBuy', 1500000),
#  ('Betaout', 1500000),
#  ('Hello Curry', 1500000),
#  ('RoomsTonite', 1500000),
#  ('iStar Skill Development', 1500000),
#  ('EarlySalary.com', 1500000),
#  ('MyCFO', 1500000),
#  ('Team Indus', 1500000),
#  ('Get My Parking', 1476000),
#  ('Baxi', 1450000),
#  ('AirMed Labs', 1400000),
#  ('UrDoorStep', 1400000),
#  ('Systemantics', 1400000),
#  ('DailyObjects', 1400000),
#  ('Ketto', 1400000),
#  ('Zenatix', 1361000),
#  ('Voxweb', 1350000),
#  ('mPaani', 1350000),
#  ('Hansel.io', 1350000),
#  ('eShakti', 1350000),
#  ('TouchKin', 1300000),
#  ('ClearTax', 1300000),
#  ('Pickingo', 1300000),
#  ('LetsTransport', 1300000),
#  ('Absentia VR', 1250000),
#  ('Noticeboard', 1200000),
#  ('BHIVE Workspace', 1200000),
#  ('Juno Clinic', 1200000),
#  ('SidQam', 1200000),
#  ('Dekkho', 1200000),
#  ('UE LifeSciences', 1200000),
#  ('Convegenius', 1200000),
#  ('YourDost', 1200000),
#  ('DocsApp', 1200000),
#  ('Affimity', 1200000),
#  ('MeraDoctor', 1200000),
#  ('Ampere Vehicles', 1200000),
#  ('Caravan Craft', 1200000),
#  ('CanvasFlip', 1200000),
#  ('SilverPush', 1200000),
#  ('Swajal', 1200000),
#  ('MapMyGenome', 1200000),
#  ('Momoe', 1200000),
#  ('PipeCandy', 1100000),
#  ('Rare Media', 1100000),
#  ('ORIGA Leasing', 1100000),
#  ('ShoppinPal', 1070000),
#  ('GoZefo', 1050000),
#  ('Billion Loans', 1000000),
#  ('Timesaverz', 1000000),
#  ('Clip App', 1000000),
#  ('Spinny', 1000000),
#  ('wayForward', 1000000),
#  ('PeeSafe.in', 1000000),
#  ('Sumeru', 1000000),
#  ('MyGreens', 1000000),
#  ('Aequm', 1000000),
#  ('The Good Life', 1000000),
#  ('EzCred', 1000000),
#  ('Video Ken', 1000000),
#  ('StalkBuyLove', 1000000),
#  ('Data Resolve', 1000000),
#  ('Zapyle', 1000000),
#  ('Wandertrails', 1000000),
#  ('NeoStencil', 1000000),
#  ('Healthifyme', 1000000),
#  ('GolfLAN', 1000000),
#  ('GramCover', 1000000),
#  ('HandyTrain', 1000000),
#  ('Remitr', 1000000),
#  ('MyKindofJob', 1000000),
#  ('OrangeTwig', 1000000),
#  ('The Kettlery', 1000000),
#  ('Talent Next', 1000000),
#  ('DoctorInsta', 1000000),
#  ('Co Life', 1000000),
#  ('HashTaag', 1000000),
#  ('Instacar', 1000000),
#  ('Yumlane', 1000000),
#  ('Fitternity', 1000000),
#  ('UnaAcademy', 1000000),
#  ('Notion Press', 1000000),
#  ('SeeDoc', 1000000),
#  ('Adytude', 1000000),
#  ('WorkApps', 1000000),
#  ('NiYO Solutions', 1000000),
#  ('Tax2Win', 1000000),
#  ('Atomberg', 1000000),
#  ('Limo', 1000000),
#  ('CreditVidya', 1000000),
#  ('Grey Campus', 1000000),
#  ('Bombay Shirt Company', 1000000),
#  ('Sminq', 1000000),
#  ('EduAce Services', 1000000),
#  ('Smartivity', 1000000),
#  ('BhiveWorkspace', 1000000),
#  ('Appie', 1000000),
#  ('Goalwise', 1000000),
#  ('Shipsy', 1000000),
#  ('MagicX', 1000000),
#  ('Legalraasta', 1000000),
#  ('Imarticus Learning', 1000000),
#  ('Aahaa', 1000000),
#  ('Nukkad Shops', 1000000),
#  ('Supplified', 1000000),
#  ('FlipClass', 1000000),
#  ('Mazkara', 1000000),
#  ('iGrenEnergi', 1000000),
#  ('TableHero', 1000000),
#  ('Baby Berry', 1000000),
#  ('Zebpay', 1000000),
#  ('SavvyMob', 1000000),
#  ('Zoctr', 1000000),
#  ('Zebi (yet to launch)', 1000000),
#  ('Streamoid', 1000000),
#  ('MobieFit', 1000000),
#  ('Town Essentials', 1000000),
#  ('BigStylist.com', 1000000),
#  ('Grab', 1000000),
#  ('Pluss', 1000000),
#  ('IndiaLends', 1000000),
#  ('Kulzy', 1000000),
#  ('Voodoo', 1000000),
#  ('S-Cube Futuretech', 1000000),
#  ('Frsh', 1000000),
#  ('Stylecracker', 1000000),
#  ('Tea Trails', 1000000),
#  ('RedDoorz', 1000000),
#  ('Eywa Media', 1000000),
#  ('ToneTag', 1000000),
#  ('HyperVerge', 1000000),
#  ('Zoojoo.be', 1000000),
#  ('Qyk App', 1000000),
#  ('Cloudcherry Analytics', 1000000),
#  ('Joy by nature', 1000000),
#  ('BroEx', 1000000),
#  ('Glamrs', 1000000),
#  ('EduKart', 1000000),
#  ('AdWyze', 1000000),
#  ('SpoonJoy', 1000000),
#  ('BuyHatke', 1000000),
#  ('Chaayos', 1000000),
#  ('MeetUniv', 1000000),
#  ('KeepTrax', 1000000),
#  ('Commeasure', 1000000),
#  ('ReGlobe', 1000000),
#  ('Niffler', 1000000),
#  ('Appedo', 1000000),
#  ('20Dresses', 1000000),
#  ('iTraveller.com', 1000000),
#  ('Trip38', 1000000),
#  ('Tookitaki', 1000000),
#  ('Thrill App', 1000000),
#  ('FR8', 971000),
#  ('BetterPlace', 970000),
#  ('ShopsUp', 963000),
#  ('Silvan Innovation Labs', 900000),
#  ('Zenify', 900000),
#  ('Luxuryhues', 900000),
#  ('FlickBay', 890000),
#  ('Click2Clinic', 850000),
#  ('Khel Now', 850000),
#  ('TempoGo', 825000),
#  ('Graphene', 825000),
#  ('Intelligence Node', 800000),
#  ('Curiositi', 800000),
#  ('Twigly', 800000),
#  ('HealthEnablr', 800000),
#  ('Virtual Logic', 800000),
#  ('Springleap', 800000),
#  ('WickedRide', 790000),
#  ('Sunday Realty Solutions', 785000),
#  ('Vista Rooms', 776000),
#  ('OnlineTyari', 770000),
#  ('Sepalika', 750000),
#  ('Actofit', 750000),
#  ('Impact Analytics', 750000),
#  ('Milofy', 750000),
#  ('kredX', 750000),
#  ('LoveCycles', 750000),
#  ('Sensara', 750000),
#  ('Justdakhila.com', 750000),
#  ('Arya.ai', 750000),
#  ('CityFlo', 750000),
#  ('Trukky', 745000),
#  ('PharmaRack', 745000),
#  ('HappilyUnmarried', 740000),
#  ('Trupay', 700000),
#  ('HipCouch', 700000),
#  ('Idea Bubbles', 700000),
#  ('Playment', 700000),
#  ('DocPlexus', 700000),
#  ('Footprints Education', 685000),
#  ('Appknox', 675000),
#  ('TopRankers', 670000),
#  ('Medinfi', 655000),
#  ('ZipLoan', 650000),
#  ('perpule', 650000),
#  ('Vahdam Teas', 650000),
#  ('Wishberry', 650000),
#  ('numberz.in', 650000),
#  ('Yellowdig', 650000),
#  ('Zuppler', 650000),
#  ('dunzo', 650000),
#  ('Grex', 650000),
#  ('Seed Schools', 650000),
#  ('Zenify.in', 640000),
#  ('Carl’s Jr', 630000),
#  ('HandyHome', 630000),
#  ('Nudgespot', 625000),
#  ('Be U Salons', 620000),
#  ('MyDreamStore', 615000),
#  ('Playablo', 600000),
#  ('GrowFitter', 600000),
#  ('Fourth Ambit', 600000),
#  ('Whodat', 600000),
#  ('Lavelle Networks', 600000),
#  ('Infisecure', 600000),
#  ('Bombay Shaving Company', 600000),
#  ('Unnati Helpers', 600000),
#  ('The Wedding Brigade', 600000),
#  ('MoMark', 600000),
#  ('DrivoJoy', 600000),
#  ('EureQa', 600000),
#  ('Delight Foods', 600000),
#  ('YouthKiAwaaz', 600000),
#  ('Bueno', 600000),
#  ('Flatpebble', 600000),
#  ('Bluegape.com', 600000),
#  ('Infinity Assurance', 600000),
#  ('Pipa Bella', 600000),
#  ('Frankly', 600000),
#  ('Diro Labs', 597000),
#  ('Truckola', 595000),
#  ('Wiwigo', 595000),
#  ('GenNext Students', 580000),
#  ('MyDidi', 550000),
#  ('Dropkaffe', 550000),
#  ('Proviera', 550000),
#  ('QwikSpec', 540000),
#  ('Vebbler', 540000),
#  ('Superhero Brands', 540000),
#  ('BiBox', 530000),
#  ('TaxSutra', 526000),
#  ('Prozo', 520000),
#  ('Orahi', 520000),
#  ('Frsh.co.in', 518000),
#  ('Silvan', 515000),
#  ('Zepo', 500000),
#  ('Boxx.ai', 500000),
#  ('MrNeeds', 500000),
#  ('Explore Life traveling', 500000),
#  ('Zapty', 500000),
#  ('ZipGrid', 500000),
#  ('Konsult App', 500000),
#  ('Karomi', 500000),
#  ('AppBrowzer', 500000),
#  ('Wigzo', 500000),
#  ('48East', 500000),
#  ('Imaginate', 500000),
#  ('Hoopy', 500000),
#  ('The BlueBook', 500000),
#  ('WorkIndia', 500000),
#  ('Pulse', 500000),
#  ('Carcrew.in', 500000),
#  ('Deyor Camps', 500000),
#  ('CreditMate', 500000),
#  ('CheersOye!', 500000),
#  ('Alternacare', 500000),
#  ('JustLikeNew', 500000),
#  ('Beardo', 500000),
#  ('Cuberoot', 500000),
#  ('Joolz', 500000),
#  ('Guarented', 500000),
#  ('Uber Dreams', 500000),
#  ('Plix', 500000),
#  ('Venture Catalysts', 500000),
#  ('ListUp', 500000),
#  ('Paytunes', 500000),
#  ('ParaBlu', 500000),
#  ('Indee', 500000),
#  ('TaxiVaxi', 500000),
#  ('Veqta', 500000),
#  ('gear6', 500000),
#  ('MilkBasket', 500000),
#  ('Impact Guru', 500000),
#  ('Shouut', 500000),
#  ('N.O.W', 500000),
#  ('Reach', 500000),
#  ('SmartVizX', 500000),
#  ('Wheelstreet', 500000),
#  ('FixNix', 500000),
#  ('Buddy', 500000),
#  ('PropheSee', 500000),
#  ('i2e1', 500000),
#  ('Bumper', 500000),
#  ('Deyor Rooms', 500000),
#  ('AppVirality', 500000),
#  ('SenseGiz', 500000),
#  ('Burger Singh', 500000),
#  ('Flexing It', 500000),
#  ('NightStay', 500000),
#  ('Appvigil', 500000),
#  ('EasyRewardz', 500000),
#  ('betaout', 500000),
#  ('ePoise', 500000),
#  ('FoodTalkIndia', 500000),
#  ('WoWexpress', 500000),
#  ('LazyLad', 500000),
#  ('Arth DesignBuild', 500000),
#  ('kWatt Solutions', 500000),
#  ('Shippr', 500000),
#  ('CouponRaja', 500000),
#  ('Vidgyor', 500000),
#  ('Retention.ai', 500000),
#  ('EveningFlavors', 500000),
#  ('ZenParent', 500000),
#  ('happay', 500000),
#  ('PiQube', 500000),
#  ('Bite Club', 500000),
#  ('Daily Rounds', 500000),
#  ('Artoo', 500000),
#  ('Klip.in', 500000),
#  ('Caravan Craft Retail', 500000),
#  ('eKincare', 491000),
#  ('Explara', 490000),
#  ('mChamp', 475000),
#  ('Hopping Chef', 470000),
#  ('Cooey', 470000),
#  ('Remit Guru', 466000),
#  ('Flickstree', 464000),
#  ('SparesHub', 460000),
#  ('Nurturey', 455000),
#  ('Fourseven', 455000),
#  ('Inner Hour', 450000),
#  ('Wittyparot', 450000),
#  ('Giftxoxo', 450000),
#  ('RoboVac', 450000),
#  ('Poshtic', 450000),
#  ('Augrav', 450000),
#  ('Oneway.cab', 450000),
#  ('Toko Innovations', 450000),
#  ('DriversCart', 450000),
#  ('TOKO Innovation Studios', 450000),
#  ('ICHR', 450000),
#  ('ZopHop', 450000),
#  ('XSTOK', 450000),
#  ('Purple Style Labs', 448000),
#  ('SillyMonks', 448000),
#  ('Mojarto', 445000),
#  ('CollegeDunia', 445000),
#  ('PeeBuddy', 443000),
#  ('Ketchupp', 441000),
#  ('iService', 440000),
#  ('WealthApp', 440000),
#  ('Math Buddy', 440000),
#  ('Flixy Games', 425000),
#  ('Myly', 410000),
#  ('WedmeGood.com', 410000),
#  ('Fitso', 400000),
#  ('Fyle', 400000),
#  ('The Ken', 400000),
#  ('World Art Community', 400000),
#  ('Celerix', 400000),
#  ('Justride', 400000),
#  ('Touchkin', 400000),
#  ('Advantage Club', 400000),
#  ('AppilyEver', 400000),
#  ('YourDOST', 400000),
#  ('AlmaMapper', 400000),
#  ('MockBank', 400000),
#  ('Furdo', 400000),
#  ('Capabiliti', 400000),
#  ('Ressy', 400000),
#  ('BookMeIn', 400000),
#  ('Belita', 400000),
#  ('LogicRoots', 400000),
#  ('Tradelab', 400000),
#  ('HealthyWorld.in', 400000),
#  ('Stitchwood', 395000),
#  ('ZippServe', 390000),
#  ('Stuffed', 385000),
#  ('Bizom', 382000),
#  ('Biryani By Kilo', 375000),
#  ('Vithi.com', 375000),
#  ('MaalGaadi', 375000),
#  ('Digio', 375000),
#  ('WebAlligator', 375000),
#  ('TripShelf', 373000),
#  ('Truce', 370000),
#  ('Biryani Blues', 368000),
#  ('CreditSeva', 360000),
#  ('Stockal', 350000),
#  ('AirZaar', 350000),
#  ('GameZop', 350000),
#  ('Ark Robot', 350000),
#  ('Muvizz', 350000),
#  ('Plabro', 350000),
#  ('Zakoopi', 350000),
#  ('Eattreatonline', 350000),
#  ('AllIzHealth', 350000),
#  ('AdStringO', 350000),
#  ('Torqus', 350000),
#  ('Refiral', 330000),
#  ('Ithaka', 325000),
#  ('Mindler', 324000),
#  ('Sattviko', 320000),
#  ...]

# %% [markdown]
# ### Now we know that we have some of the names written incorrectly. So we need to correct them and then run the program again

# %%
df.StartupName.replace('Ola Cabs', 'Ola', inplace = True)
df.StartupName.replace('Olacabs', 'Ola', inplace = True)
df.StartupName.replace('Oyo Rooms', 'Oyo', inplace = True)
df.StartupName.replace('Paytm Marketplace', 'Paytm', inplace = True)
df.StartupName.replace('Oyorooms', 'Oyo', inplace = True)
df.StartupName.replace('OyoRooms', 'Oyo', inplace = True)
df.StartupName.replace('OYO Rooms', 'Ola', inplace = True)
df.StartupName.replace('Flipkart.com', 'Flipkart', inplace = True)

# %%
startup = np.array(df.StartupName)
startup_amount = {}
for i in range(len(amount)):
    current_startup = startup[i]
    
    startup_amount[current_startup] = startup_amount.get(current_startup, 0) + amount[i]
    
startup_amount

ans = sorted(startup_amount.items(), key = lambda x : x[1], reverse = True)

ans
# Out:
# [('Paytm', 2340000000),
#  ('Flipkart', 2259700000),
#  ('Ola', 1924500000),
#  ('Snapdeal', 700000000),
#  ('Oyo', 612000000),
#  ('Quikr', 230000000),
#  ('Delhivery', 215000000),
#  ('Foodpanda', 210000000),
#  ('BigBasket', 207000000),
#  ('MakeMyTrip', 180000000),
#  ('Hike', 175000000),
#  ('Swiggy', 170500000),
#  ('Grofers', 165000000),
#  ('Byju’s', 160000000),
#  ('CarTrade', 145000000),
#  ('FreeCharge', 137000000),
#  ('Ecom Express', 137000000),
#  ('Pepperfry', 131300000),
#  ('Rivigo', 120000000),
#  ('Shopclues', 107700000),
#  ('Saavn', 100000000),
#  ('Fractal Analytics', 100000000),
#  ('Inmobi', 100000000),
#  ('ShopClues', 100000000),
#  ('Mobikwik', 90000000),
#  ('practo', 90000000),
#  ('YepMe', 88700000),
#  ('Practo', 85000000),
#  ('Zomato', 85000000),
#  ('BookMyShow', 82000000),
#  ('Chillr', 76000000),
#  ('Meru Cabs', 75000000),
#  ('BillDesk', 75000000),
#  ('Ace2three', 73700000),
#  ('Blackbuck', 70000000),
#  ('Urban Ladder', 65200000),
#  ('Infogain', 63000000),
#  ('UrbanClap', 60700000),
#  ('Lenskart', 60000000),
#  ('BankBazaar', 60000000),
#  ('Manthan', 60000000),
#  ('Markets and Markets', 56000000),
#  ('Antuit', 56000000),
#  ('Cartrade', 55000000),
#  ('FreshDesk', 55000000),
#  ('Naaptol', 52000000),
#  ('Druva', 51000000),
#  ('Goomo', 50000000),
#  ('Yupp TV', 50000000),
#  ('Netmeds.com', 50000000),
#  ('Zovi.com / Little App', 50000000),
#  ('Homelane', 50000000),
#  ('Freshdesk', 50000000),
#  ('CarDekho.com', 50000000),
#  ('RateGain', 50000000),
#  ('Icertis', 46000000),
#  ('Capillary Tech', 45000000),
#  ('Zo Rooms', 45000000),
#  ('LendingKart', 44450000),
#  ('Capital Float', 42800000),
#  ('Furlenco', 41000000),
#  ('Healthcare at Home', 40000000),
#  ('Peppertap', 40000000),
#  ('Zivame', 40000000),
#  ('Vistaar Finance', 40000000),
#  ('Applied Solar Technologies', 40000000),
#  ('PolicyBazaar', 40000000),
#  ('NewsHunt', 40000000),
#  ('Ather Energy', 39000000),
#  ('Portea Medical', 37500000),
#  ('Puro Wellness', 37000000),
#  ('Faasos', 36300000),
#  ('Simplilearn', 35750000),
#  ('TicketNew', 35000000),
#  ('Amagi Media Labs', 35000000),
#  ('EPS', 35000000),
#  ('Saama', 35000000),
#  ('Voonik', 34000000),
#  ('CraftsVilla', 34000000),
#  ('FreshMenu', 33500000),
#  ('MobiKwik', 31600000),
#  ('NestAway', 31300000),
#  ('mSwipe', 31000000),
#  ('Power2SME', 31000000),
#  ('Medwell Ventures', 31000000),
#  ('Caratlane.com', 31000000),
#  ('1mg', 30000000),
#  ('BlueStone', 30000000),
#  ('Roposo', 30000000),
#  ('Qubole', 30000000),
#  ('CredR', 30000000),
#  ('Grey Orange', 30000000),
#  ('Paper Boat', 30000000),
#  ('Axtria', 30000000),
#  ('deGustibus', 30000000),
#  ('LimeRoad.com', 30000000),
#  ('Square Yards', 28000000),
#  ('Sulekha.com', 28000000),
#  ('S Chand', 27000000),
#  ('Housejoy', 26500000),
#  ('Jugnoo', 26000000),
#  ('FirstCry', 26000000),
#  ('Fab Hotels', 25000000),
#  ('DailyHunt', 25000000),
#  ('Hungama', 25000000),
#  ('BlackBuck', 25000000),
#  ('Citrus Payment', 25000000),
#  ('Ezetap', 25000000),
#  ('IFMR Holdings', 25000000),
#  ('Mswipe', 25000000),
#  ('ZoomCar', 24000000),
#  ('Hopscotch', 24000000),
#  ('TinyOwl', 23500000),
#  ('Innoviti', 23350000),
#  ('Koovs', 23300000),
#  ('Pi Data Centers', 23000000),
#  ('HelpShift', 23000000),
#  ('CCAvenue', 22400000),
#  ('Flytxt', 22000000),
#  ('Nykaa', 21800000),
#  ('Naaptol.com', 21500000),
#  ('Roadrunnr', 21000000),
#  ('NoBroker', 20400000),
#  ('Droom', 20000000),
#  ('Awfis', 20000000),
#  ('Housing.com', 20000000),
#  ('Knowlarity', 20000000),
#  ('Just Buy Live', 20000000),
#  ('Shuttl', 20000000),
#  ('NDTV Wedding portal', 20000000),
#  ('GoJavas', 20000000),
#  ('Allygrow Technologies', 20000000),
#  ('MebelKart', 20000000),
#  ('News in shorts', 20000000),
#  ('MedGenome', 20000000),
#  ('Zopper', 20000000),
#  ('Groupon India', 20000000),
#  ('Faaso’s', 20000000),
#  ('Stayzilla', 20000000),
#  ('iGenetics', 19500000),
#  ('Loylty Rewards', 19350000),
#  ('CueMath', 19000000),
#  ('Zeta', 19000000),
#  ('PharmEasy', 18000000),
#  ('Travel Triangle', 18000000),
#  ('InnoNano Research', 18000000),
#  ('Craftstvilla', 18000000),
#  ('Culture Machine', 18000000),
#  ('Vyomo', 17000000),
#  ('Magicpin', 16600000),
#  ('Bidgely', 16600000),
#  ('Itzcash', 16500000),
#  ('Moglix', 16200000),
#  ('Bluestone', 16200000),
#  ('OfBusiness', 16100000),
#  ('Zoomcar', 16000000),
#  ('Rentalpha', 16000000),
#  ('NeoGrowth', 16000000),
#  ('StoreKing', 16000000),
#  ('NearBuy (previously\xa0 groupon India)', 16000000),
#  ('Droom.in', 16000000),
#  ('La Renon', 16000000),
#  ('Akosha', 16000000),
#  ('Aryaka', 16000000),
#  ('Appsdaily', 16000000),
#  ('Innovaccer', 15600000),
#  ('CoverFox', 15000000),
#  ('Ixigo', 15000000),
#  ('Better Mortgage', 15000000),
#  ('True Balance', 15000000),
#  ('BYJU’s', 15000000),
#  ('Flexiloans', 15000000),
#  ('Zenoti', 15000000),
#  ('LivSpace', 15000000),
#  ('Curefit', 15000000),
#  ('Deal4Loans / Wishfin', 15000000),
#  ('Transerv', 15000000),
#  ('Yuvi Hospitality', 15000000),
#  ('TaskBucks', 15000000),
#  ('Voylla', 15000000),
#  ('HolidayIQ', 15000000),
#  ('Arkin Net', 15000000),
#  ('Indix', 15000000),
#  ('Fintellix', 15000000),
#  ('Vserv', 15000000),
#  ('MoonFrog Labs', 15000000),
#  ('Mahindra First Choice', 15000000),
#  ('TruckingCube', 14900000),
#  ('Agrostar', 14000000),
#  ('Licious', 14000000),
#  ('Cleartax', 14000000),
#  ('Kartrocket', 14000000),
#  ('Coverfox', 14000000),
#  ('StayZilla', 13500000),
#  ('ZenDrive', 13500000),
#  ('Tracxn', 13500000),
#  ('NxtGen', 13500000),
#  ('GoQii', 13400000),
#  ('Toppr', 13200000),
#  ('Leap India', 13000000),
#  ('IndustryBuying', 13000000),
#  ('Nestaway', 12750000),
#  ('Unbxd', 12500000),
#  ('Xpressbees', 12500000),
#  ('MindTickle', 12500000),
#  ('MoneyTap', 12300000),
#  ('SirionLabs', 12250000),
#  ('Box8', 12000000),
#  ('HealthKart', 12000000),
#  ('Seclore', 12000000),
#  ('Robosoft', 12000000),
#  ('MyGlamm', 11300000),
#  ('Big Fish Ventures', 11100000),
#  ('Aye Finance', 11000000),
#  ('CupoNation', 11000000),
#  ('FundsIndia.com', 11000000),
#  ('Lybrate', 10200000),
#  ('CreditMantri', 10100000),
#  ('Rentomojo', 10000000),
#  ('4tigo', 10000000),
#  ('Belong', 10000000),
#  ('Zapr', 10000000),
#  ('NowFloats', 10000000),
#  ('Xseed Education', 10000000),
#  ('Indifi', 10000000),
#  ('IdeaForge', 10000000),
#  ('Shadowfox', 10000000),
#  ('EasyPolicy', 10000000),
#  ('Udaan', 10000000),
#  ('Travelyaari', 10000000),
#  ('Sagacito', 10000000),
#  ('EduPristine', 10000000),
#  ('The Viral Fever', 10000000),
#  ('Holisol Logistics', 10000000),
#  ('SportzVillage', 10000000),
#  ('Grabhouse', 10000000),
#  ('Attune Technologies', 10000000),
#  ('ChaiPoint', 10000000),
#  ('LogiNext', 10000000),
#  ('Lendingkart', 10000000),
#  ('Mamagoto', 10000000),
#  ('MySmartPrice', 10000000),
#  ('Trucksfirst', 10000000),
#  ('FirstCry.com', 10000000),
#  ('ZopNow', 10000000),
#  ('PepperTap', 10000000),
#  ('Babajobs', 10000000),
#  ('Arohan Financial Services', 10000000),
#  ('Smartairtrip.com', 10000000),
#  ('#Fame', 10000000),
#  ('NumberMall', 10000000),
#  ('Zilingo', 9900000),
#  ('Wizrocket', 9600000),
#  ('Clovia', 9000000),
#  ('Revv', 9000000),
#  ('QikPod', 9000000),
#  ('Razorpay', 9000000),
#  ('Shadowfax', 9000000),
#  ('CCavenue', 8900000),
#  ('Infibeam', 8800000),
#  ('Truebil', 8650000),
#  ('Fusion Microfinance', 8600000),
#  ('Jumbotail', 8500000),
#  ('Ninjacart', 8500000),
#  ('Opinio', 8300000),
#  ('Eruditus', 8200000),
#  ('MyDentist', 8200000),
#  ('Wooplr', 8000000),
#  ('Postman', 8000000),
#  ('FabHotels', 8000000),
#  ('Cloud Lending', 8000000),
#  ('Livspace', 8000000),
#  ('WeAreHolidays', 7700000),
#  ('Cube26', 7700000),
#  ('OneAssist', 7500000),
#  ('Flutura', 7500000),
#  ('Zarget', 7500000),
#  ('StyleTag', 7500000),
#  ('Collectabillia', 7500000),
#  ('HackerRank', 7500000),
#  ('SnapBizz', 7200000),
#  ('ElastiRun', 7000000),
#  ('Runnr', 7000000),
#  ('Flyrobe', 7000000),
#  ('Villgro', 6750000),
#  ('Oho Shop', 6700000),
#  ('Mihup', 6700000),
#  ('ZestMoney', 6500000),
#  ('Zest Money', 6500000),
#  ('Aasaanjobs', 6500000),
#  ('Avanti Learning', 6500000),
#  ('CultureAlley', 6500000),
#  ('LatestOne', 6350000),
#  ('Gadgetwood', 6200000),
#  ('Perfios', 6100000),
#  ('Mech Mocha', 6000000),
#  ('Stalk Buy Love', 6000000),
#  ('Connect India', 6000000),
#  ('Zefo', 6000000),
#  ('ISFC', 6000000),
#  ('Kredx', 6000000),
#  ('CloudCherry', 6000000),
#  ('Purplle', 6000000),
#  ('Ridlr', 6000000),
#  ('Teabox', 6000000),
#  ('Jivox', 6000000),
#  ('PrettySecrets', 6000000),
#  ('Schedulers Logistics', 6000000),
#  ('HealthifyMe', 6000000),
#  ('B9 Beverages', 6000000),
#  ('Chefs Basket', 6000000),
#  ('Welcome Cure', 6000000),
#  ('ManageMySpa', 6000000),
#  ('Veeba Foods', 6000000),
#  ('Treebo', 6000000),
#  ('The Porter', 6000000),
#  ('Zinka', 6000000),
#  ('1mg (Healthkartplus)', 6000000),
#  ('Lookup', 5880000),
#  ('Sigtuple', 5800000),
#  ('Juspay', 5800000),
#  ('Taskbob', 5700000),
#  ('LensKart', 5650000),
#  ('Patel Logistics', 5600000),
#  ('CureJoy', 5550000),
#  ('Goodera', 5500000),
#  ('Crown-it', 5500000),
#  ('TrulyMadly.com', 5500000),
#  ('ShareChat', 5350000),
#  ('Paysense', 5300000),
#  ('HolaChef', 5275000),
#  ('Insider.in', 5200000),
#  ('Julia Computing', 5200000),
#  ('Wassup', 5200000),
#  ('Canvera', 5200000),
#  ('GreytHR', 5200000),
#  ('HUG Innovations', 5000000),
#  ('Stashfin', 5000000),
#  ('Tagos Design', 5000000),
#  ('Ace Turtle', 5000000),
#  ('Legal Raasta', 5000000),
#  ('SastaSundar', 5000000),
#  ('Indus OS', 5000000),
#  ('Securens', 5000000),
#  ('Unacademy', 5000000),
#  ('ZoloStays', 5000000),
#  ('ShopX', 5000000),
#  ('JustRide', 5000000),
#  ('Stasis Labs', 5000000),
#  ('Vymo', 5000000),
#  ('Mystifly', 5000000),
#  ('YAAP', 5000000),
#  ('RentMojo', 5000000),
#  ('Jaypore', 5000000),
#  ('AlefMobitech', 5000000),
#  ('Melorra', 5000000),
#  ('HomeStudio', 5000000),
#  ('Shotang.com', 5000000),
#  ('Pokkt', 5000000),
#  ('Parcelled', 5000000),
#  ('Infoworks', 5000000),
#  ('Gozoomo', 5000000),
#  ('Liases Foras', 5000000),
#  ('Ameyo', 5000000),
#  ('Bona Vita', 5000000),
#  ('Hansa Customer Equity', 5000000),
#  ('belong', 5000000),
#  ('Vedantu', 5000000),
#  ('IndianRoots.com', 5000000),
#  ('Casa2inns', 5000000),
#  ('LocalOye', 5000000),
#  ('ChargeBee', 5000000),
#  ('DiabetOmics', 5000000),
#  ('Drivestream', 5000000),
#  ('Roposo.com', 5000000),
#  ('Wooplr.com', 5000000),
#  ('Commonfloor', 5000000),
#  ('Capricoast', 4750000),
#  ('Veritas Finance', 4700000),
#  ('FastFox', 4600000),
#  ('Whatfix', 4590000),
#  ('Grow Fit', 4500000),
#  ('Emiza', 4500000),
#  ('HackerEarth', 4500000),
#  ('MagicBricks', 4500000),
#  ('Customfurnish', 4500000),
#  ('HomeLane', 4500000),
#  ('Printvenue', 4500000),
#  ('Care24', 4350000),
#  ('MoEngage', 4250000),
#  ('InnerChef', 4250000),
#  ('KOOH Sports', 4200000),
#  ('IntelligenceNODE', 4200000),
#  ('NewsInShorts', 4150000),
#  ('Roambee', 4100000),
#  ('Vayana', 4000000),
#  ('DarwinBox', 4000000),
#  ('Loantap', 4000000),
#  ('V Resorts', 4000000),
#  ('Early Salary', 4000000),
#  ('Lets Transport', 4000000),
#  ('RML Agtech', 4000000),
#  ('India Lends', 4000000),
#  ('PlaySimple', 4000000),
#  ('medECUBE', 4000000),
#  ('Altizone', 4000000),
#  ('RKSV', 4000000),
#  ('icustommadeit', 4000000),
#  ('IMbesharam', 4000000),
#  ('Buildzar', 4000000),
#  ('ScoopWhoop', 4000000),
#  ('RevX', 4000000),
#  ('Reverie', 4000000),
#  ('Meritnation', 4000000),
#  ('Pastiwala', 4000000),
#  ('Cashe', 3800000),
#  ('AppsDaily', 3750000),
#  ('Goodbox', 3700000),
#  ('Cashkaro.com', 3700000),
#  ('Airpay', 3670000),
#  ('Blowhorn', 3650000),
#  ('Scootsy', 3600000),
#  ('Slide App', 3600000),
#  ('TinyStep', 3580000),
#  ('Collateral Medical', 3500000),
#  ('Active.ai', 3500000),
#  ('Affordplan', 3500000),
#  ('Trak N Tell', 3500000),
#  ('FarEye', 3500000),
#  ('Eat.Shop.Love', 3500000),
#  ('Fynd', 3400000),
#  ('Quintype', 3300000),
#  ('POPxo', 3100000),
#  ('Holachef', 3100000),
#  ('Autorox.co', 3000000),
#  ('EazyDiner', 3000000),
#  ('Rubique', 3000000),
#  ('Healthians', 3000000),
#  ('CureFit', 3000000),
#  ('Telr', 3000000),
#  ('Fingerlix', 3000000),
#  ('Oriano Solar', 3000000),
#  ('YourStory', 3000000),
#  ('Heads Up For Tails', 3000000),
#  ('TYGR', 3000000),
#  ('Pocket Aces', 3000000),
#  ('Bizongo', 3000000),
#  ('NetLinx', 3000000),
#  ('Inuxu', 3000000),
#  ('UrbanLadder', 3000000),
#  ('Cult', 3000000),
#  ('LoanTap', 3000000),
#  ('Overcart.com', 3000000),
#  ('Bonhomia', 3000000),
#  ('LEAP India', 3000000),
#  ('CollegeDekho', 3000000),
#  ('MyCity4Kids', 3000000),
#  ('CREO', 3000000),
#  ('Yumist', 3000000),
#  ('Jigsaw Academy', 3000000),
#  ('Whoop', 3000000),
#  ('HeyPillow', 3000000),
#  ('SchoolGuru', 3000000),
#  ('UE Life Sciences', 3000000),
#  ('Bestdealfinance', 3000000),
#  ('Doormint', 3000000),
#  ('Wudstay', 3000000),
#  ('Propstack', 3000000),
#  ('Fracktal Works', 3000000),
#  ('Lets Corp', 3000000),
#  ('Triphobo', 3000000),
#  ('MyNoticePeriod', 3000000),
#  ('Nimble Wireless', 3000000),
#  ('AgentDesks', 2950000),
#  ('Graphic India', 2800000),
#  ('Locus', 2750000),
#  ('WayCool', 2700000),
#  ('Dil Mil', 2700000),
#  ('Ecolibriumenergy', 2600000),
#  ('Renderlogy', 2600000),
#  ('Sheroes', 2570000),
#  ('Celes Care', 2500000),
#  ('Red Carpet', 2500000),
#  ('Doctor Insta', 2500000),
#  ('MySUN', 2500000),
#  ('NearBuy', 2500000),
#  ('Tokri', 2500000),
#  ('Scripbox', 2500000),
#  ('MyGubbi', 2500000),
#  ('EduBridge', 2500000),
#  ('Paynear', 2500000),
#  ('Flatchat', 2500000),
#  ('CustomFurnish.com', 2500000),
#  ('Crowdfire (formerly Justunfollow)', 2500000),
#  ('Grabhouse.com', 2500000),
#  ('Vidooly', 2400000),
#  ('TimeSaverz', 2400000),
#  ('Zimmber', 2400000),
#  ('trueHb', 2400000),
#  ('Pragmatix', 2400000),
#  ('iBus Networks', 2300000),
#  ('Mobikon', 2300000),
#  ('Fabogo', 2250000),
#  ('Loan Frame', 2250000),
#  ('Juggernaut', 2250000),
#  ('InstaSafe', 2200000),
#  ('WoW Express', 2200000),
#  ('Easypolicy', 2200000),
#  ('PressPlay', 2200000),
#  ('BigStylist', 2150000),
#  ('Squadrun', 2100000),
#  ('Increff', 2000000),
#  ('PortDesk', 2000000),
#  ('Kissht', 2000000),
#  ('Niki.ai', 2000000),
#  ('Fitpass', 2000000),
#  ('Innefu Security Consulting', 2000000),
#  ('Weddingz.in', 2000000),
#  ('Fresh Food Concepts', 2000000),
#  ('enKast', 2000000),
#  ('IIM Jobs', 2000000),
#  ('ElasticRun', 2000000),
#  ('WholeSaleBox', 2000000),
#  ('MarianaIQ', 2000000),
#  ('Uniphore', 2000000),
#  ('India Gifts Portal', 2000000),
#  ('FabAlley', 2000000),
#  ('CropIn', 2000000),
#  ('Grab.in', 2000000),
#  ('AppDaily', 2000000),
#  ('BankerBay', 2000000),
#  ('Vyome Biosciences', 2000000),
#  ('KrazyBee', 2000000),
#  ('EPayLater', 2000000),
#  ('Room On Call', 2000000),
#  ('Gingercrush', 2000000),
#  ('Godof Hospitals', 2000000),
#  ('Bluebirch', 2000000),
#  ('TruckMandi', 2000000),
#  ('POPxo.com', 2000000),
#  ('RentoMojo', 2000000),
#  ('Shopalyst', 2000000),
#  ('ZuperMeal', 2000000),
#  ('Tripoto', 2000000),
#  ('Toppr.com', 2000000),
#  ('RoomCentral', 2000000),
#  ('Fourth Partner Energy', 2000000),
#  ('Iqlect', 2000000),
#  ('Prothom', 2000000),
#  ('Uniken', 2000000),
#  ('ZapStitch', 2000000),
#  ('Plancess', 2000000),
#  ('UrbanPro', 2000000),
#  ('Fxkart.com', 2000000),
#  ('Satvacart', 1800000),
#  ('Sahayog Dairy', 1800000),
#  ('HeadOut', 1800000),
#  ('PickMe', 1790000),
#  ('Faircent.com', 1750000),
#  ('Teewe', 1750000),
#  ('Chumbak', 1700000),
#  ('Springboard', 1700000),
#  ('Supr Daily', 1620000),
#  ('Fisdom', 1600000),
#  ('MyTaxiIndia', 1600000),
#  ('WOW! MOMO', 1600000),
#  ('QuikWallet', 1600000),
#  ('Goodservice', 1600000),
#  ('Applicate', 1550000),
#  ('White Owl Brewery', 1530000),
#  ('Multiplier Solutions', 1500000),
#  ('ABI Health', 1500000),
#  ('Innovapptive', 1500000),
#  ('CrediHealth', 1500000),
#  ('Howdy Ventures', 1500000),
#  ('iNurture', 1500000),
#  ('Mad Street Den', 1500000),
#  ('GoPigeon', 1500000),
#  ('Unocoin', 1500000),
#  ('Petoo', 1500000),
#  ('Crofarm', 1500000),
#  ('SaleBhai', 1500000),
#  ('Velvetcase', 1500000),
#  ('SchoolWear', 1500000),
#  ('Address Health', 1500000),
#  ('RenewBuy', 1500000),
#  ('Betaout', 1500000),
#  ('Hello Curry', 1500000),
#  ('RoomsTonite', 1500000),
#  ('iStar Skill Development', 1500000),
#  ('EarlySalary.com', 1500000),
#  ('MyCFO', 1500000),
#  ('Team Indus', 1500000),
#  ('Get My Parking', 1476000),
#  ('Baxi', 1450000),
#  ('AirMed Labs', 1400000),
#  ('UrDoorStep', 1400000),
#  ('Systemantics', 1400000),
#  ('DailyObjects', 1400000),
#  ('Ketto', 1400000),
#  ('Zenatix', 1361000),
#  ('Voxweb', 1350000),
#  ('mPaani', 1350000),
#  ('Hansel.io', 1350000),
#  ('eShakti', 1350000),
#  ('TouchKin', 1300000),
#  ('ClearTax', 1300000),
#  ('Pickingo', 1300000),
#  ('LetsTransport', 1300000),
#  ('Absentia VR', 1250000),
#  ('Noticeboard', 1200000),
#  ('BHIVE Workspace', 1200000),
#  ('Juno Clinic', 1200000),
#  ('SidQam', 1200000),
#  ('Dekkho', 1200000),
#  ('UE LifeSciences', 1200000),
#  ('Convegenius', 1200000),
#  ('YourDost', 1200000),
#  ('DocsApp', 1200000),
#  ('Affimity', 1200000),
#  ('MeraDoctor', 1200000),
#  ('Ampere Vehicles', 1200000),
#  ('Caravan Craft', 1200000),
#  ('CanvasFlip', 1200000),
#  ('SilverPush', 1200000),
#  ('Swajal', 1200000),
#  ('MapMyGenome', 1200000),
#  ('Momoe', 1200000),
#  ('PipeCandy', 1100000),
#  ('Rare Media', 1100000),
#  ('ORIGA Leasing', 1100000),
#  ('ShoppinPal', 1070000),
#  ('GoZefo', 1050000),
#  ('Billion Loans', 1000000),
#  ('Timesaverz', 1000000),
#  ('Clip App', 1000000),
#  ('Spinny', 1000000),
#  ('wayForward', 1000000),
#  ('PeeSafe.in', 1000000),
#  ('Sumeru', 1000000),
#  ('MyGreens', 1000000),
#  ('Aequm', 1000000),
#  ('The Good Life', 1000000),
#  ('EzCred', 1000000),
#  ('Video Ken', 1000000),
#  ('StalkBuyLove', 1000000),
#  ('Data Resolve', 1000000),
#  ('Zapyle', 1000000),
#  ('Wandertrails', 1000000),
#  ('NeoStencil', 1000000),
#  ('Healthifyme', 1000000),
#  ('GolfLAN', 1000000),
#  ('GramCover', 1000000),
#  ('HandyTrain', 1000000),
#  ('Remitr', 1000000),
#  ('MyKindofJob', 1000000),
#  ('OrangeTwig', 1000000),
#  ('The Kettlery', 1000000),
#  ('Talent Next', 1000000),
#  ('DoctorInsta', 1000000),
#  ('Co Life', 1000000),
#  ('HashTaag', 1000000),
#  ('Instacar', 1000000),
#  ('Yumlane', 1000000),
#  ('Fitternity', 1000000),
#  ('UnaAcademy', 1000000),
#  ('Notion Press', 1000000),
#  ('SeeDoc', 1000000),
#  ('Adytude', 1000000),
#  ('WorkApps', 1000000),
#  ('NiYO Solutions', 1000000),
#  ('Tax2Win', 1000000),
#  ('Atomberg', 1000000),
#  ('Limo', 1000000),
#  ('CreditVidya', 1000000),
#  ('Grey Campus', 1000000),
#  ('Bombay Shirt Company', 1000000),
#  ('Sminq', 1000000),
#  ('EduAce Services', 1000000),
#  ('Smartivity', 1000000),
#  ('BhiveWorkspace', 1000000),
#  ('Appie', 1000000),
#  ('Goalwise', 1000000),
#  ('Shipsy', 1000000),
#  ('MagicX', 1000000),
#  ('Legalraasta', 1000000),
#  ('Imarticus Learning', 1000000),
#  ('Aahaa', 1000000),
#  ('Nukkad Shops', 1000000),
#  ('Supplified', 1000000),
#  ('FlipClass', 1000000),
#  ('Mazkara', 1000000),
#  ('iGrenEnergi', 1000000),
#  ('TableHero', 1000000),
#  ('Baby Berry', 1000000),
#  ('Zebpay', 1000000),
#  ('SavvyMob', 1000000),
#  ('Zoctr', 1000000),
#  ('Zebi (yet to launch)', 1000000),
#  ('Streamoid', 1000000),
#  ('MobieFit', 1000000),
#  ('Town Essentials', 1000000),
#  ('BigStylist.com', 1000000),
#  ('Grab', 1000000),
#  ('Pluss', 1000000),
#  ('IndiaLends', 1000000),
#  ('Kulzy', 1000000),
#  ('Voodoo', 1000000),
#  ('S-Cube Futuretech', 1000000),
#  ('Frsh', 1000000),
#  ('Stylecracker', 1000000),
#  ('Tea Trails', 1000000),
#  ('RedDoorz', 1000000),
#  ('Eywa Media', 1000000),
#  ('ToneTag', 1000000),
#  ('HyperVerge', 1000000),
#  ('Zoojoo.be', 1000000),
#  ('Qyk App', 1000000),
#  ('Cloudcherry Analytics', 1000000),
#  ('Joy by nature', 1000000),
#  ('BroEx', 1000000),
#  ('Glamrs', 1000000),
#  ('EduKart', 1000000),
#  ('AdWyze', 1000000),
#  ('SpoonJoy', 1000000),
#  ('BuyHatke', 1000000),
#  ('Chaayos', 1000000),
#  ('MeetUniv', 1000000),
#  ('KeepTrax', 1000000),
#  ('Commeasure', 1000000),
#  ('ReGlobe', 1000000),
#  ('Niffler', 1000000),
#  ('Appedo', 1000000),
#  ('20Dresses', 1000000),
#  ('iTraveller.com', 1000000),
#  ('Trip38', 1000000),
#  ('Tookitaki', 1000000),
#  ('Thrill App', 1000000),
#  ('FR8', 971000),
#  ('BetterPlace', 970000),
#  ('ShopsUp', 963000),
#  ('Silvan Innovation Labs', 900000),
#  ('Zenify', 900000),
#  ('Luxuryhues', 900000),
#  ('FlickBay', 890000),
#  ('Click2Clinic', 850000),
#  ('Khel Now', 850000),
#  ('TempoGo', 825000),
#  ('Graphene', 825000),
#  ('Intelligence Node', 800000),
#  ('Curiositi', 800000),
#  ('Twigly', 800000),
#  ('HealthEnablr', 800000),
#  ('Virtual Logic', 800000),
#  ('Springleap', 800000),
#  ('WickedRide', 790000),
#  ('Sunday Realty Solutions', 785000),
#  ('Vista Rooms', 776000),
#  ('OnlineTyari', 770000),
#  ('Sepalika', 750000),
#  ('Actofit', 750000),
#  ('Impact Analytics', 750000),
#  ('Milofy', 750000),
#  ('kredX', 750000),
#  ('LoveCycles', 750000),
#  ('Sensara', 750000),
#  ('Justdakhila.com', 750000),
#  ('Arya.ai', 750000),
#  ('CityFlo', 750000),
#  ('Trukky', 745000),
#  ('PharmaRack', 745000),
#  ('HappilyUnmarried', 740000),
#  ('Trupay', 700000),
#  ('HipCouch', 700000),
#  ('Idea Bubbles', 700000),
#  ('Playment', 700000),
#  ('DocPlexus', 700000),
#  ('Footprints Education', 685000),
#  ('Appknox', 675000),
#  ('TopRankers', 670000),
#  ('Medinfi', 655000),
#  ('ZipLoan', 650000),
#  ('perpule', 650000),
#  ('Vahdam Teas', 650000),
#  ('Wishberry', 650000),
#  ('numberz.in', 650000),
#  ('Yellowdig', 650000),
#  ('Zuppler', 650000),
#  ('dunzo', 650000),
#  ('Grex', 650000),
#  ('Seed Schools', 650000),
#  ('Zenify.in', 640000),
#  ('Carl’s Jr', 630000),
#  ('HandyHome', 630000),
#  ('Nudgespot', 625000),
#  ('Be U Salons', 620000),
#  ('MyDreamStore', 615000),
#  ('Playablo', 600000),
#  ('GrowFitter', 600000),
#  ('Fourth Ambit', 600000),
#  ('Whodat', 600000),
#  ('Lavelle Networks', 600000),
#  ('Infisecure', 600000),
#  ('Bombay Shaving Company', 600000),
#  ('Unnati Helpers', 600000),
#  ('The Wedding Brigade', 600000),
#  ('MoMark', 600000),
#  ('DrivoJoy', 600000),
#  ('EureQa', 600000),
#  ('Delight Foods', 600000),
#  ('YouthKiAwaaz', 600000),
#  ('Bueno', 600000),
#  ('Flatpebble', 600000),
#  ('Bluegape.com', 600000),
#  ('Infinity Assurance', 600000),
#  ('Pipa Bella', 600000),
#  ('Frankly', 600000),
#  ('Diro Labs', 597000),
#  ('Truckola', 595000),
#  ('Wiwigo', 595000),
#  ('GenNext Students', 580000),
#  ('MyDidi', 550000),
#  ('Dropkaffe', 550000),
#  ('Proviera', 550000),
#  ('QwikSpec', 540000),
#  ('Vebbler', 540000),
#  ('Superhero Brands', 540000),
#  ('BiBox', 530000),
#  ('TaxSutra', 526000),
#  ('Prozo', 520000),
#  ('Orahi', 520000),
#  ('Frsh.co.in', 518000),
#  ('Silvan', 515000),
#  ('Zepo', 500000),
#  ('Boxx.ai', 500000),
#  ('MrNeeds', 500000),
#  ('Explore Life traveling', 500000),
#  ('Zapty', 500000),
#  ('ZipGrid', 500000),
#  ('Konsult App', 500000),
#  ('Karomi', 500000),
#  ('AppBrowzer', 500000),
#  ('Wigzo', 500000),
#  ('48East', 500000),
#  ('Imaginate', 500000),
#  ('Hoopy', 500000),
#  ('The BlueBook', 500000),
#  ('WorkIndia', 500000),
#  ('Pulse', 500000),
#  ('Carcrew.in', 500000),
#  ('Deyor Camps', 500000),
#  ('CreditMate', 500000),
#  ('CheersOye!', 500000),
#  ('Alternacare', 500000),
#  ('JustLikeNew', 500000),
#  ('Beardo', 500000),
#  ('Cuberoot', 500000),
#  ('Joolz', 500000),
#  ('Guarented', 500000),
#  ('Uber Dreams', 500000),
#  ('Plix', 500000),
#  ('Venture Catalysts', 500000),
#  ('ListUp', 500000),
#  ('Paytunes', 500000),
#  ('ParaBlu', 500000),
#  ('Indee', 500000),
#  ('TaxiVaxi', 500000),
#  ('Veqta', 500000),
#  ('gear6', 500000),
#  ('MilkBasket', 500000),
#  ('Impact Guru', 500000),
#  ('Shouut', 500000),
#  ('N.O.W', 500000),
#  ('Reach', 500000),
#  ('SmartVizX', 500000),
#  ('Wheelstreet', 500000),
#  ('FixNix', 500000),
#  ('Buddy', 500000),
#  ('PropheSee', 500000),
#  ('i2e1', 500000),
#  ('Bumper', 500000),
#  ('Deyor Rooms', 500000),
#  ('AppVirality', 500000),
#  ('SenseGiz', 500000),
#  ('Burger Singh', 500000),
#  ('Flexing It', 500000),
#  ('NightStay', 500000),
#  ('Appvigil', 500000),
#  ('EasyRewardz', 500000),
#  ('betaout', 500000),
#  ('ePoise', 500000),
#  ('FoodTalkIndia', 500000),
#  ('WoWexpress', 500000),
#  ('LazyLad', 500000),
#  ('Arth DesignBuild', 500000),
#  ('kWatt Solutions', 500000),
#  ('Shippr', 500000),
#  ('CouponRaja', 500000),
#  ('Vidgyor', 500000),
#  ('Retention.ai', 500000),
#  ('EveningFlavors', 500000),
#  ('ZenParent', 500000),
#  ('happay', 500000),
#  ('PiQube', 500000),
#  ('Bite Club', 500000),
#  ('Daily Rounds', 500000),
#  ('Artoo', 500000),
#  ('Klip.in', 500000),
#  ('Caravan Craft Retail', 500000),
#  ('eKincare', 491000),
#  ('Explara', 490000),
#  ('mChamp', 475000),
#  ('Hopping Chef', 470000),
#  ('Cooey', 470000),
#  ('Remit Guru', 466000),
#  ('Flickstree', 464000),
#  ('SparesHub', 460000),
#  ('Nurturey', 455000),
#  ('Fourseven', 455000),
#  ('Inner Hour', 450000),
#  ('Wittyparot', 450000),
#  ('Giftxoxo', 450000),
#  ('RoboVac', 450000),
#  ('Poshtic', 450000),
#  ('Augrav', 450000),
#  ('Oneway.cab', 450000),
#  ('Toko Innovations', 450000),
#  ('DriversCart', 450000),
#  ('TOKO Innovation Studios', 450000),
#  ('ICHR', 450000),
#  ('ZopHop', 450000),
#  ('XSTOK', 450000),
#  ('Purple Style Labs', 448000),
#  ('SillyMonks', 448000),
#  ('Mojarto', 445000),
#  ('CollegeDunia', 445000),
#  ('PeeBuddy', 443000),
#  ('Ketchupp', 441000),
#  ('iService', 440000),
#  ('WealthApp', 440000),
#  ('Math Buddy', 440000),
#  ('Flixy Games', 425000),
#  ('Myly', 410000),
#  ('WedmeGood.com', 410000),
#  ('Fitso', 400000),
#  ('Fyle', 400000),
#  ('The Ken', 400000),
#  ('World Art Community', 400000),
#  ('Celerix', 400000),
#  ('Justride', 400000),
#  ('Touchkin', 400000),
#  ('Advantage Club', 400000),
#  ('AppilyEver', 400000),
#  ('YourDOST', 400000),
#  ('AlmaMapper', 400000),
#  ('MockBank', 400000),
#  ('Furdo', 400000),
#  ('Capabiliti', 400000),
#  ('Ressy', 400000),
#  ('BookMeIn', 400000),
#  ('Belita', 400000),
#  ('LogicRoots', 400000),
#  ('Tradelab', 400000),
#  ('HealthyWorld.in', 400000),
#  ('Stitchwood', 395000),
#  ('ZippServe', 390000),
#  ('Stuffed', 385000),
#  ('Bizom', 382000),
#  ('Biryani By Kilo', 375000),
#  ('Vithi.com', 375000),
#  ('MaalGaadi', 375000),
#  ('Digio', 375000),
#  ('WebAlligator', 375000),
#  ('TripShelf', 373000),
#  ('Truce', 370000),
#  ('Biryani Blues', 368000),
#  ('CreditSeva', 360000),
#  ('Stockal', 350000),
#  ('AirZaar', 350000),
#  ('GameZop', 350000),
#  ('Ark Robot', 350000),
#  ('Muvizz', 350000),
#  ('Plabro', 350000),
#  ('Zakoopi', 350000),
#  ('Eattreatonline', 350000),
#  ('AllIzHealth', 350000),
#  ('AdStringO', 350000),
#  ('Torqus', 350000),
#  ('Refiral', 330000),
#  ('Ithaka', 325000),
#  ('Mindler', 324000),
#  ('Sattviko', 320000),
#  ('LoanBaba', 320000),
#  ('Myonsto', 320000),
#  ('The/Nudge Foundation', 315000),
#  ('VioletStreet', 315000),
#  ('Spares Hub', 311000),
#  ('Quifers', 310000),
#  ('ShadowFax', 310000),
#  ('Black White Orange', 303000),
#  ...]

# %%
ans = ans[:5]
ans
# Out:
# [('Paytm', 2340000000),
#  ('Flipkart', 2259700000),
#  ('Ola', 1924500000),
#  ('Snapdeal', 700000000),
#  ('Oyo', 612000000)]

# %% [markdown]
# ### Creating a Pie chart with the percentage of amount in each startup (Among the top 5 startups)

# %%
total = 0
for i in ans:
    total += i[1]
    
percentage = []
startups = []
for i in range(5):
    percentage.append((ans[i][1] / total ) * 100)
    startups.append(ans[i][0])
    
print(startups)
print(percentage)
# Out:
# ['Paytm', 'Flipkart', 'Ola', 'Snapdeal', 'Oyo']
# [29.861412419284854, 28.836681044383756, 24.559097521757995, 8.932901151068119, 7.809907863505271]

# %%
plt.pie(percentage, autopct = "%.2f%%")
plt.axis("equal")
plt.legend(startups)

plt.show()
